# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import pickle

from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC

from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.metrics import roc_auc_score, accuracy_score, f1_score, precision_score, recall_score, confusion_matrix
from sklearn.model_selection import RandomizedSearchCV

from catboost import CatBoostClassifier
from sklearn import tree
from sklearn.tree import _tree


import xgboost as xgb

SEED = 42

# %% [markdown]
# # Filename to save/load models

# %%
filename = '../models/test 65%/'

# %% [markdown]
# # Functions defining

# %%
def get_rules(tree, feature_names, class_names):
    tree_ = tree.tree_
    feature_name = [
        feature_names[i] if i != _tree.TREE_UNDEFINED else "undefined!"
        for i in tree_.feature
    ]

    paths = []
    path = []
    
    def recurse(node, path, paths):
        
        if tree_.feature[node] != _tree.TREE_UNDEFINED:
            name = feature_name[node]
            threshold = tree_.threshold[node]
            p1, p2 = list(path), list(path)
            p1 += [f"({name} <= {np.round(threshold, 3)})"]
            recurse(tree_.children_left[node], p1, paths)
            p2 += [f"({name} > {np.round(threshold, 3)})"]
            recurse(tree_.children_right[node], p2, paths)
        else:
            path += [(tree_.value[node], tree_.n_node_samples[node])]
            paths += [path]
            
    recurse(0, path, paths)

    # sort by samples count
    samples_count = [p[-1][1] for p in paths]
    ii = list(np.argsort(samples_count))
    paths = [paths[i] for i in reversed(ii)]
    
    rules = []
    for path in paths:
        rule = "if "
        
        for p in path[:-1]:
            if rule != "if ":
                rule += " and "
            rule += str(p)
        rule += " then "
        if class_names is None:
            rule += "response: "+str(np.round(path[-1][0][0][0],3))
        else:
            classes = path[-1][0][0]
            l = np.argmax(classes)
            rule += f"class: {class_names[l]} (proba: {np.round(100.0*classes[l]/np.sum(classes),2)}%)"
        rule += f" | based on {path[-1][1]:,} samples"
        rules += [rule]
        
    return rules

# %%
def print_scores(y_true, y_pred):
    print('ROCAUC score:',roc_auc_score(y_true, y_pred).round(4))
    print('Accuracy score:',accuracy_score(y_true, y_pred).round(4))
    print('F1 score:',f1_score(y_true, y_pred).round(4))
    print('Precision score:',precision_score(y_true, y_pred).round(4))
    print('Recall:',recall_score(y_true, y_pred).round(4))

def run_model(model, X_train, y_train, X_test, y_test):
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    score = accuracy_score(y_test, y_pred)
    return score, y_pred

def tune_model(model, param_grid, n_iter, X_train, y_train):
    grid = RandomizedSearchCV(model, param_grid, verbose=20,
        scoring='roc_auc', cv=3, n_iter=n_iter)
    grid.fit(X_train, y_train)
    best_model = grid.best_estimator_
    return best_model

# %% [markdown]
# # Load data

# %%
df = pd.read_csv('../data/Parameters_90%stability.csv')
df = df.drop(['Unnamed: 0'], axis = 1)
df.head(3)
# Out:
#    Gamma_AATA  Gamma_IPPS   Gamma_IPPSm  Gamma_DHQTi    Gamma_ADCS  \
# 0    0.072899    0.005997  7.820000e-15     0.006337  4.840000e-08
# 1    0.072899    0.005997  7.820000e-15     0.006337  4.840000e-08
# 2    0.071643    0.006483  3.750000e-15     0.006192  4.870000e-08
#
#    Gamma_ABTA  Gamma_PGL  Gamma_ACACT1r  Gamma_ACOAHim  Gamma_ACOTAim  ...  \
# 0    0.976899   0.081794       0.906322   5.030000e-12       0.198783  ...
# 1    0.976899   0.081794       0.906322   5.030000e-12       0.198783  ...
# 2    0.976932   0.089406       0.906766   3.250000e-12       0.200557  ...
#
#    sigma_km_product_ccm2tp  sigma_km_substrate_pca2tp  \
# 0                 0.333927                   0.112272
# 1                 0.693616                   0.302981
# 2                 0.333927                   0.112272
#
#    sigma_km_product_pca2tp  sigma_km_substrate_r2073_1  \
# 0                 0.241996                    0.580106
# 1                 0.761936                    0.059439
# 2                 0.241996                    0.580106
#
#    sigma_km_product_r2073_1  sigma_km_substrate1_r_4235  \
# 0                  0.658892                    0.950488
# 1                  0.938477                    0.722462
# 2                  0.658892                    0.950488
#
#    sigma_km_product1_r_4235  sigma_km_substrate2_r_4235  \
# 0                  0.214360                    0.271523
# 1                  0.442469                    0.426947
# 2                  0.214360                    0.271523
#
#    sigma_km_product2_r_4235  Stability
# 0                  0.527818          1
# 1                  0.517426          0
# 2                  0.527818          0
#
# [3 rows x 1411 columns]

# %%
df.shape
# Out:
# (372, 1411)

# %% [markdown]
# # Look at target variable

# %%
sns.countplot(data=df, x='Stability')
plt.show()

# %%
SI = len(df[df['Stability']==1])/len(df) * 100
print("The Stability Index is: SI =",round(SI, 4), "%")
# Out:
# The Stability Index is: SI = 19.6237 %

# %% [markdown]
# Imbalanced dataset

# %% [markdown]
# # Split train - test

# %%
from sklearn.model_selection import train_test_split

# Load X and Y 
X = df.drop(['Stability'], axis = 1)
y = df['Stability']

x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=.35,
                                                stratify=y, random_state=SEED)

y_train = pd.DataFrame(y_train)
y_test = pd.DataFrame(y_test)

# %%
print('train',x_train.shape)
print('test',x_test.shape)
# Out:
# train (241, 1410)
# test (131, 1410)

# %%
SI_train = len(y_train[y_train['Stability']==1])/len(y_train) * 100
print("The Stability Index on TRAIN SET is: SI =",round(SI_train, 4), "%")

SI_test = len(y_test[y_test['Stability']==1])/len(y_test) * 100
print("The Stability Index on TEST SET is: SI =",round(SI_test, 4), "%")
# Out:
# The Stability Index on TRAIN SET is: SI = 19.5021 %
# The Stability Index on TEST SET is: SI = 19.8473 %

# %% [markdown]
# # _Feature_names_ and _class_names_

# %%
class_names = y_train['Stability'].unique().astype(str)
feature_names = x_train.columns.values

# %% [markdown]
# # Normalize data

# %%
scaler = StandardScaler()

X_train = scaler.fit_transform(x_train)
X_test = scaler.transform(x_test)

X_train = pd.DataFrame(X_train, columns=x_train.columns)
X_train.index = x_train.index

X_test = pd.DataFrame(X_test, columns=x_test.columns)
X_test.index = x_test.index

# %% [markdown]
# # BLACK-BOX MODEL

# %%
try:
    
    # load the model from disk
    best_svc = pickle.load(open(filename+'/svc_model.sav', 'rb'))

except FileNotFoundError:

    # =================
    # SVC
    # =================

    param_grid_svc = {'C': [0.001, 0.005, 0.01, 0.02, 0.05, 0.08, 1, 1.5, 2, 2.5, 3, 5, 10, 12, 20, 25, 50],
                'gamma': [0.002, 0.003, 0.004, 0.001, 0.005, 0.01, 0.05, 0.1, 0.2, 0.5],
                'kernel': ['rbf', 'linear']
    }

    svc = SVC(random_state=SEED)
    best_svc = tune_model(svc, param_grid_svc, 1000, X_train, y_train.values.ravel())
    score, y_pred_svc = run_model(best_svc, X_train, y_train.values.ravel(),
        X_test, y_test.values.ravel())

    pickle.dump(best_svc, open(filename+'/svc_model.sav', 'wb'))
# Out:
# /home/comex/.local/lib/python3.8/site-packages/sklearn/model_selection/_search.py:306: UserWarning: The total space of parameters 340 is smaller than n_iter=1000. Running 340 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# Fitting 3 folds for each of 340 candidates, totalling 1020 fits
# [CV 1/3; 1/340] START C=0.001, gamma=0.002, kernel=rbf..........................
# [CV 1/3; 1/340] END C=0.001, gamma=0.002, kernel=rbf;, score=0.831 total time=   0.2s
# [CV 2/3; 1/340] START C=0.001, gamma=0.002, kernel=rbf..........................
# [CV 2/3; 1/340] END C=0.001, gamma=0.002, kernel=rbf;, score=0.739 total time=   0.1s
# [CV 3/3; 1/340] START C=0.001, gamma=0.002, kernel=rbf..........................
# [CV 3/3; 1/340] END C=0.001, gamma=0.002, kernel=rbf;, score=0.807 total time=   0.0s
# [CV 1/3; 2/340] START C=0.001, gamma=0.002, kernel=linear.......................
# [CV 1/3; 2/340] END C=0.001, gamma=0.002, kernel=linear;, score=0.867 total time=   0.0s
# [CV 2/3; 2/340] START C=0.001, gamma=0.002, kernel=linear.......................
# [CV 2/3; 2/340] END C=0.001, gamma=0.002, kernel=linear;, score=0.777 total time=   0.0s
# [CV 3/3; 2/340] START C=0.001, gamma=0.002, kernel=linear.......................
# [CV 3/3; 2/340] END C=0.001, gamma=0.002, kernel=linear;, score=0.890 total time=   0.0s
# [CV 1/3; 3/340] START C=0.001, gamma=0.003, kernel=rbf..........................
# [CV 1/3; 3/340] END C=0.001, gamma=0.003, kernel=rbf;, score=0.844 total time=   0.0s
# [CV 2/3; 3/340] START C=0.001, gamma=0.003, kernel=rbf..........................
# [CV 2/3; 3/340] END C=0.001, gamma=0.003, kernel=rbf;, score=0.686 total time=   0.0s
# [CV 3/3; 3/340] START C=0.001, gamma=0.003, kernel=rbf..........................
# [CV 3/3; 3/340] END C=0.001, gamma=0.003, kernel=rbf;, score=0.811 total time=   0.0s
# [CV 1/3; 4/340] START C=0.001, gamma=0.003, kernel=linear.......................
# [CV 1/3; 4/340] END C=0.001, gamma=0.003, kernel=linear;, score=0.867 total time=   0.0s
# [CV 2/3; 4/340] START C=0.001, gamma=0.003, kernel=linear.......................
# [CV 2/3; 4/340] END C=0.001, gamma=0.003, kernel=linear;, score=0.777 total time=   0.0s
# [CV 3/3; 4/340] START C=0.001, gamma=0.003, kernel=linear.......................
# [CV 3/3; 4/340] END C=0.001, gamma=0.003, kernel=linear;, score=0.890 total time=   0.0s
# [CV 1/3; 5/340] START C=0.001, gamma=0.004, kernel=rbf..........................
# [CV 1/3; 5/340] END C=0.001, gamma=0.004, kernel=rbf;, score=0.886 total time=   0.0s
# [CV 2/3; 5/340] START C=0.001, gamma=0.004, kernel=rbf..........................
# [CV 2/3; 5/340] END C=0.001, gamma=0.004, kernel=rbf;, score=0.659 total time=   0.0s
# [CV 3/3; 5/340] START C=0.001, gamma=0.004, kernel=rbf..........................
# [CV 3/3; 5/340] END C=0.001, gamma=0.004, kernel=rbf;, score=0.812 total time=   0.0s
# [CV 1/3; 6/340] START C=0.001, gamma=0.004, kernel=linear.......................
# [CV 1/3; 6/340] END C=0.001, gamma=0.004, kernel=linear;, score=0.867 total time=   0.0s
# [CV 2/3; 6/340] START C=0.001, gamma=0.004, kernel=linear.......................
# [CV 2/3; 6/340] END C=0.001, gamma=0.004, kernel=linear;, score=0.777 total time=   0.0s
# [CV 3/3; 6/340] START C=0.001, gamma=0.004, kernel=linear.......................
# [CV 3/3; 6/340] END C=0.001, gamma=0.004, kernel=linear;, score=0.890 total time=   0.0s
# [CV 1/3; 7/340] START C=0.001, gamma=0.001, kernel=rbf..........................
# [CV 1/3; 7/340] END C=0.001, gamma=0.001, kernel=rbf;, score=0.837 total time=   0.0s
# [CV 2/3; 7/340] START C=0.001, gamma=0.001, kernel=rbf..........................
# [CV 2/3; 7/340] END C=0.001, gamma=0.001, kernel=rbf;, score=0.754 total time=   0.0s
# [CV 3/3; 7/340] START C=0.001, gamma=0.001, kernel=rbf..........................
# [CV 3/3; 7/340] END C=0.001, gamma=0.001, kernel=rbf;, score=0.840 total time=   0.0s
# [CV 1/3; 8/340] START C=0.001, gamma=0.001, kernel=linear.......................
# [CV 1/3; 8/340] END C=0.001, gamma=0.001, kernel=linear;, score=0.867 total time=   0.0s
# [CV 2/3; 8/340] START C=0.001, gamma=0.001, kernel=linear.......................
# [CV 2/3; 8/340] END C=0.001, gamma=0.001, kernel=linear;, score=0.777 total time=   0.0s
# [CV 3/3; 8/340] START C=0.001, gamma=0.001, kernel=linear.......................
# [CV 3/3; 8/340] END C=0.001, gamma=0.001, kernel=linear;, score=0.890 total time=   0.0s
# [CV 1/3; 9/340] START C=0.001, gamma=0.005, kernel=rbf..........................
# [CV 1/3; 9/340] END C=0.001, gamma=0.005, kernel=rbf;, score=0.862 total time=   0.0s
# [CV 2/3; 9/340] START C=0.001, gamma=0.005, kernel=rbf..........................
# [CV 2/3; 9/340] END C=0.001, gamma=0.005, kernel=rbf;, score=0.656 total time=   0.0s
# [CV 3/3; 9/340] START C=0.001, gamma=0.005, kernel=rbf..........................
# [CV 3/3; 9/340] END C=0.001, gamma=0.005, kernel=rbf;, score=0.815 total time=   0.0s
# [CV 1/3; 10/340] START C=0.001, gamma=0.005, kernel=linear......................
# [CV 1/3; 10/340] END C=0.001, gamma=0.005, kernel=linear;, score=0.867 total time=   0.0s
# [CV 2/3; 10/340] START C=0.001, gamma=0.005, kernel=linear......................
# [CV 2/3; 10/340] END C=0.001, gamma=0.005, kernel=linear;, score=0.777 total time=   0.0s
# [CV 3/3; 10/340] START C=0.001, gamma=0.005, kernel=linear......................
# [CV 3/3; 10/340] END C=0.001, gamma=0.005, kernel=linear;, score=0.890 total time=   0.0s
# [CV 1/3; 11/340] START C=0.001, gamma=0.01, kernel=rbf..........................
# [CV 1/3; 11/340] END C=0.001, gamma=0.01, kernel=rbf;, score=0.906 total time=   0.0s
# [CV 2/3; 11/340] START C=0.001, gamma=0.01, kernel=rbf..........................
# [CV 2/3; 11/340] END C=0.001, gamma=0.01, kernel=rbf;, score=0.639 total time=   0.0s
# [CV 3/3; 11/340] START C=0.001, gamma=0.01, kernel=rbf..........................
# [CV 3/3; 11/340] END C=0.001, gamma=0.01, kernel=rbf;, score=0.812 total time=   0.0s
# [CV 1/3; 12/340] START C=0.001, gamma=0.01, kernel=linear.......................
# [CV 1/3; 12/340] END C=0.001, gamma=0.01, kernel=linear;, score=0.867 total time=   0.0s
# [CV 2/3; 12/340] START C=0.001, gamma=0.01, kernel=linear.......................
# [CV 2/3; 12/340] END C=0.001, gamma=0.01, kernel=linear;, score=0.777 total time=   0.0s
# [CV 3/3; 12/340] START C=0.001, gamma=0.01, kernel=linear.......................
# [CV 3/3; 12/340] END C=0.001, gamma=0.01, kernel=linear;, score=0.890 total time=   0.0s
# [CV 1/3; 13/340] START C=0.001, gamma=0.05, kernel=rbf..........................
# [CV 1/3; 13/340] END C=0.001, gamma=0.05, kernel=rbf;, score=0.844 total time=   0.0s
# [CV 2/3; 13/340] START C=0.001, gamma=0.05, kernel=rbf..........................
# [CV 2/3; 13/340] END C=0.001, gamma=0.05, kernel=rbf;, score=0.565 total time=   0.0s
# [CV 3/3; 13/340] START C=0.001, gamma=0.05, kernel=rbf..........................
# [CV 3/3; 13/340] END C=0.001, gamma=0.05, kernel=rbf;, score=0.771 total time=   0.0s
# [CV 1/3; 14/340] START C=0.001, gamma=0.05, kernel=linear.......................
# [CV 1/3; 14/340] END C=0.001, gamma=0.05, kernel=linear;, score=0.867 total time=   0.0s
# [CV 2/3; 14/340] START C=0.001, gamma=0.05, kernel=linear.......................
# [CV 2/3; 14/340] END C=0.001, gamma=0.05, kernel=linear;, score=0.777 total time=   0.0s
# [CV 3/3; 14/340] START C=0.001, gamma=0.05, kernel=linear.......................
# [CV 3/3; 14/340] END C=0.001, gamma=0.05, kernel=linear;, score=0.890 total time=   0.0s
# [CV 1/3; 15/340] START C=0.001, gamma=0.1, kernel=rbf...........................
# [CV 1/3; 15/340] END C=0.001, gamma=0.1, kernel=rbf;, score=0.820 total time=   0.0s
# [CV 2/3; 15/340] START C=0.001, gamma=0.1, kernel=rbf...........................
# [CV 2/3; 15/340] END C=0.001, gamma=0.1, kernel=rbf;, score=0.633 total time=   0.0s
# [CV 3/3; 15/340] START C=0.001, gamma=0.1, kernel=rbf...........................
# [CV 3/3; 15/340] END C=0.001, gamma=0.1, kernel=rbf;, score=0.720 total time=   0.0s
# [CV 1/3; 16/340] START C=0.001, gamma=0.1, kernel=linear........................
# [CV 1/3; 16/340] END C=0.001, gamma=0.1, kernel=linear;, score=0.867 total time=   0.0s
# [CV 2/3; 16/340] START C=0.001, gamma=0.1, kernel=linear........................
# [CV 2/3; 16/340] END C=0.001, gamma=0.1, kernel=linear;, score=0.777 total time=   0.0s
# [CV 3/3; 16/340] START C=0.001, gamma=0.1, kernel=linear........................
# [CV 3/3; 16/340] END C=0.001, gamma=0.1, kernel=linear;, score=0.890 total time=   0.0s
# [CV 1/3; 17/340] START C=0.001, gamma=0.2, kernel=rbf...........................
# [CV 1/3; 17/340] END C=0.001, gamma=0.2, kernel=rbf;, score=0.818 total time=   0.0s
# [CV 2/3; 17/340] START C=0.001, gamma=0.2, kernel=rbf...........................
# [CV 2/3; 17/340] END C=0.001, gamma=0.2, kernel=rbf;, score=0.636 total time=   0.0s
# [CV 3/3; 17/340] START C=0.001, gamma=0.2, kernel=rbf...........................
# [CV 3/3; 17/340] END C=0.001, gamma=0.2, kernel=rbf;, score=0.717 total time=   0.0s
# [CV 1/3; 18/340] START C=0.001, gamma=0.2, kernel=linear........................
# [CV 1/3; 18/340] END C=0.001, gamma=0.2, kernel=linear;, score=0.867 total time=   0.0s
# [CV 2/3; 18/340] START C=0.001, gamma=0.2, kernel=linear........................
# [CV 2/3; 18/340] END C=0.001, gamma=0.2, kernel=linear;, score=0.777 total time=   0.0s
# [CV 3/3; 18/340] START C=0.001, gamma=0.2, kernel=linear........................
# [CV 3/3; 18/340] END C=0.001, gamma=0.2, kernel=linear;, score=0.890 total time=   0.0s
# [CV 1/3; 19/340] START C=0.001, gamma=0.5, kernel=rbf...........................
# [CV 1/3; 19/340] END C=0.001, gamma=0.5, kernel=rbf;, score=0.749 total time=   0.0s
# [CV 2/3; 19/340] START C=0.001, gamma=0.5, kernel=rbf...........................
# [CV 2/3; 19/340] END C=0.001, gamma=0.5, kernel=rbf;, score=0.647 total time=   0.0s
# [CV 3/3; 19/340] START C=0.001, gamma=0.5, kernel=rbf...........................
# [CV 3/3; 19/340] END C=0.001, gamma=0.5, kernel=rbf;, score=0.667 total time=   0.0s
# [CV 1/3; 20/340] START C=0.001, gamma=0.5, kernel=linear........................
# [CV 1/3; 20/340] END C=0.001, gamma=0.5, kernel=linear;, score=0.867 total time=   0.0s
# [CV 2/3; 20/340] START C=0.001, gamma=0.5, kernel=linear........................
# [CV 2/3; 20/340] END C=0.001, gamma=0.5, kernel=linear;, score=0.777 total time=   0.0s
# [CV 3/3; 20/340] START C=0.001, gamma=0.5, kernel=linear........................
# [CV 3/3; 20/340] END C=0.001, gamma=0.5, kernel=linear;, score=0.890 total time=   0.0s
# [CV 1/3; 21/340] START C=0.005, gamma=0.002, kernel=rbf.........................
# [CV 1/3; 21/340] END C=0.005, gamma=0.002, kernel=rbf;, score=0.837 total time=   0.1s
# [CV 2/3; 21/340] START C=0.005, gamma=0.002, kernel=rbf.........................
# [CV 2/3; 21/340] END C=0.005, gamma=0.002, kernel=rbf;, score=0.636 total time=   0.0s
# [CV 3/3; 21/340] START C=0.005, gamma=0.002, kernel=rbf.........................
# [CV 3/3; 21/340] END C=0.005, gamma=0.002, kernel=rbf;, score=0.807 total time=   0.0s
# [CV 1/3; 22/340] START C=0.005, gamma=0.002, kernel=linear......................
# [CV 1/3; 22/340] END C=0.005, gamma=0.002, kernel=linear;, score=0.913 total time=   0.0s
# [CV 2/3; 22/340] START C=0.005, gamma=0.002, kernel=linear......................
# [CV 2/3; 22/340] END C=0.005, gamma=0.002, kernel=linear;, score=0.841 total time=   0.0s
# [CV 3/3; 22/340] START C=0.005, gamma=0.002, kernel=linear......................
# [CV 3/3; 22/340] END C=0.005, gamma=0.002, kernel=linear;, score=0.883 total time=   0.0s
# [CV 1/3; 23/340] START C=0.005, gamma=0.003, kernel=rbf.........................
# [CV 1/3; 23/340] END C=0.005, gamma=0.003, kernel=rbf;, score=0.859 total time=   0.1s
# [CV 2/3; 23/340] START C=0.005, gamma=0.003, kernel=rbf.........................
# [CV 2/3; 23/340] END C=0.005, gamma=0.003, kernel=rbf;, score=0.610 total time=   0.0s
# [CV 3/3; 23/340] START C=0.005, gamma=0.003, kernel=rbf.........................
# [CV 3/3; 23/340] END C=0.005, gamma=0.003, kernel=rbf;, score=0.769 total time=   0.0s
# [CV 1/3; 24/340] START C=0.005, gamma=0.003, kernel=linear......................
# [CV 1/3; 24/340] END C=0.005, gamma=0.003, kernel=linear;, score=0.913 total time=   0.0s
# [CV 2/3; 24/340] START C=0.005, gamma=0.003, kernel=linear......................
# [CV 2/3; 24/340] END C=0.005, gamma=0.003, kernel=linear;, score=0.841 total time=   0.0s
# [CV 3/3; 24/340] START C=0.005, gamma=0.003, kernel=linear......................
# [CV 3/3; 24/340] END C=0.005, gamma=0.003, kernel=linear;, score=0.883 total time=   0.0s
# [CV 1/3; 25/340] START C=0.005, gamma=0.004, kernel=rbf.........................
# [CV 1/3; 25/340] END C=0.005, gamma=0.004, kernel=rbf;, score=0.880 total time=   0.1s
# [CV 2/3; 25/340] START C=0.005, gamma=0.004, kernel=rbf.........................
# [CV 2/3; 25/340] END C=0.005, gamma=0.004, kernel=rbf;, score=0.613 total time=   0.0s
# [CV 3/3; 25/340] START C=0.005, gamma=0.004, kernel=rbf.........................
# [CV 3/3; 25/340] END C=0.005, gamma=0.004, kernel=rbf;, score=0.799 total time=   0.0s
# [CV 1/3; 26/340] START C=0.005, gamma=0.004, kernel=linear......................
# [CV 1/3; 26/340] END C=0.005, gamma=0.004, kernel=linear;, score=0.913 total time=   0.0s
# [CV 2/3; 26/340] START C=0.005, gamma=0.004, kernel=linear......................
# [CV 2/3; 26/340] END C=0.005, gamma=0.004, kernel=linear;, score=0.841 total time=   0.0s
# [CV 3/3; 26/340] START C=0.005, gamma=0.004, kernel=linear......................
# [CV 3/3; 26/340] END C=0.005, gamma=0.004, kernel=linear;, score=0.883 total time=   0.0s
# [CV 1/3; 27/340] START C=0.005, gamma=0.001, kernel=rbf.........................
# [CV 1/3; 27/340] END C=0.005, gamma=0.001, kernel=rbf;, score=0.877 total time=   0.0s
# [CV 2/3; 27/340] START C=0.005, gamma=0.001, kernel=rbf.........................
# [CV 2/3; 27/340] END C=0.005, gamma=0.001, kernel=rbf;, score=0.654 total time=   0.0s
# [CV 3/3; 27/340] START C=0.005, gamma=0.001, kernel=rbf.........................
# [CV 3/3; 27/340] END C=0.005, gamma=0.001, kernel=rbf;, score=0.850 total time=   0.1s
# [CV 1/3; 28/340] START C=0.005, gamma=0.001, kernel=linear......................
# [CV 1/3; 28/340] END C=0.005, gamma=0.001, kernel=linear;, score=0.913 total time=   0.0s
# [CV 2/3; 28/340] START C=0.005, gamma=0.001, kernel=linear......................
# [CV 2/3; 28/340] END C=0.005, gamma=0.001, kernel=linear;, score=0.841 total time=   0.0s
# [CV 3/3; 28/340] START C=0.005, gamma=0.001, kernel=linear......................
# [CV 3/3; 28/340] END C=0.005, gamma=0.001, kernel=linear;, score=0.883 total time=   0.0s
# [CV 1/3; 29/340] START C=0.005, gamma=0.005, kernel=rbf.........................
# [CV 1/3; 29/340] END C=0.005, gamma=0.005, kernel=rbf;, score=0.881 total time=   0.0s
# [CV 2/3; 29/340] START C=0.005, gamma=0.005, kernel=rbf.........................
# [CV 2/3; 29/340] END C=0.005, gamma=0.005, kernel=rbf;, score=0.627 total time=   0.0s
# [CV 3/3; 29/340] START C=0.005, gamma=0.005, kernel=rbf.........................
# [CV 3/3; 29/340] END C=0.005, gamma=0.005, kernel=rbf;, score=0.766 total time=   0.1s
# [CV 1/3; 30/340] START C=0.005, gamma=0.005, kernel=linear......................
# [CV 1/3; 30/340] END C=0.005, gamma=0.005, kernel=linear;, score=0.913 total time=   0.0s
# [CV 2/3; 30/340] START C=0.005, gamma=0.005, kernel=linear......................
# [CV 2/3; 30/340] END C=0.005, gamma=0.005, kernel=linear;, score=0.841 total time=   0.0s
# [CV 3/3; 30/340] START C=0.005, gamma=0.005, kernel=linear......................
# [CV 3/3; 30/340] END C=0.005, gamma=0.005, kernel=linear;, score=0.883 total time=   0.0s
# [CV 1/3; 31/340] START C=0.005, gamma=0.01, kernel=rbf..........................
# [CV 1/3; 31/340] END C=0.005, gamma=0.01, kernel=rbf;, score=0.881 total time=   0.1s
# [CV 2/3; 31/340] START C=0.005, gamma=0.01, kernel=rbf..........................
# [CV 2/3; 31/340] END C=0.005, gamma=0.01, kernel=rbf;, score=0.609 total time=   0.1s
# [CV 3/3; 31/340] START C=0.005, gamma=0.01, kernel=rbf..........................
# [CV 3/3; 31/340] END C=0.005, gamma=0.01, kernel=rbf;, score=0.771 total time=   0.1s
# [CV 1/3; 32/340] START C=0.005, gamma=0.01, kernel=linear.......................
# [CV 1/3; 32/340] END C=0.005, gamma=0.01, kernel=linear;, score=0.913 total time=   0.0s
# [CV 2/3; 32/340] START C=0.005, gamma=0.01, kernel=linear.......................
# [CV 2/3; 32/340] END C=0.005, gamma=0.01, kernel=linear;, score=0.841 total time=   0.0s
# [CV 3/3; 32/340] START C=0.005, gamma=0.01, kernel=linear.......................
# [CV 3/3; 32/340] END C=0.005, gamma=0.01, kernel=linear;, score=0.883 total time=   0.0s
# [CV 1/3; 33/340] START C=0.005, gamma=0.05, kernel=rbf..........................
# [CV 1/3; 33/340] END C=0.005, gamma=0.05, kernel=rbf;, score=0.864 total time=   0.1s
# [CV 2/3; 33/340] START C=0.005, gamma=0.05, kernel=rbf..........................
# [CV 2/3; 33/340] END C=0.005, gamma=0.05, kernel=rbf;, score=0.536 total time=   0.1s
# [CV 3/3; 33/340] START C=0.005, gamma=0.05, kernel=rbf..........................
# [CV 3/3; 33/340] END C=0.005, gamma=0.05, kernel=rbf;, score=0.832 total time=   0.1s
# [CV 1/3; 34/340] START C=0.005, gamma=0.05, kernel=linear.......................
# [CV 1/3; 34/340] END C=0.005, gamma=0.05, kernel=linear;, score=0.913 total time=   0.0s
# [CV 2/3; 34/340] START C=0.005, gamma=0.05, kernel=linear.......................
# [CV 2/3; 34/340] END C=0.005, gamma=0.05, kernel=linear;, score=0.841 total time=   0.0s
# [CV 3/3; 34/340] START C=0.005, gamma=0.05, kernel=linear.......................
# [CV 3/3; 34/340] END C=0.005, gamma=0.05, kernel=linear;, score=0.883 total time=   0.0s
# [CV 1/3; 35/340] START C=0.005, gamma=0.1, kernel=rbf...........................
# [CV 1/3; 35/340] END C=0.005, gamma=0.1, kernel=rbf;, score=0.831 total time=   0.1s
# [CV 2/3; 35/340] START C=0.005, gamma=0.1, kernel=rbf...........................
# [CV 2/3; 35/340] END C=0.005, gamma=0.1, kernel=rbf;, score=0.570 total time=   0.1s
# [CV 3/3; 35/340] START C=0.005, gamma=0.1, kernel=rbf...........................
# [CV 3/3; 35/340] END C=0.005, gamma=0.1, kernel=rbf;, score=0.785 total time=   0.1s
# [CV 1/3; 36/340] START C=0.005, gamma=0.1, kernel=linear........................
# [CV 1/3; 36/340] END C=0.005, gamma=0.1, kernel=linear;, score=0.913 total time=   0.0s
# [CV 2/3; 36/340] START C=0.005, gamma=0.1, kernel=linear........................
# [CV 2/3; 36/340] END C=0.005, gamma=0.1, kernel=linear;, score=0.841 total time=   0.0s
# [CV 3/3; 36/340] START C=0.005, gamma=0.1, kernel=linear........................
# [CV 3/3; 36/340] END C=0.005, gamma=0.1, kernel=linear;, score=0.883 total time=   0.0s
# [CV 1/3; 37/340] START C=0.005, gamma=0.2, kernel=rbf...........................
# [CV 1/3; 37/340] END C=0.005, gamma=0.2, kernel=rbf;, score=0.830 total time=   0.1s
# [CV 2/3; 37/340] START C=0.005, gamma=0.2, kernel=rbf...........................
# [CV 2/3; 37/340] END C=0.005, gamma=0.2, kernel=rbf;, score=0.574 total time=   0.1s
# [CV 3/3; 37/340] START C=0.005, gamma=0.2, kernel=rbf...........................
# [CV 3/3; 37/340] END C=0.005, gamma=0.2, kernel=rbf;, score=0.791 total time=   0.1s
# [CV 1/3; 38/340] START C=0.005, gamma=0.2, kernel=linear........................
# [CV 1/3; 38/340] END C=0.005, gamma=0.2, kernel=linear;, score=0.913 total time=   0.0s
# [CV 2/3; 38/340] START C=0.005, gamma=0.2, kernel=linear........................
# [CV 2/3; 38/340] END C=0.005, gamma=0.2, kernel=linear;, score=0.841 total time=   0.0s
# [CV 3/3; 38/340] START C=0.005, gamma=0.2, kernel=linear........................
# [CV 3/3; 38/340] END C=0.005, gamma=0.2, kernel=linear;, score=0.883 total time=   0.0s
# [CV 1/3; 39/340] START C=0.005, gamma=0.5, kernel=rbf...........................
# [CV 1/3; 39/340] END C=0.005, gamma=0.5, kernel=rbf;, score=0.754 total time=   0.1s
# [CV 2/3; 39/340] START C=0.005, gamma=0.5, kernel=rbf...........................
# [CV 2/3; 39/340] END C=0.005, gamma=0.5, kernel=rbf;, score=0.647 total time=   0.1s
# [CV 3/3; 39/340] START C=0.005, gamma=0.5, kernel=rbf...........................
# [CV 3/3; 39/340] END C=0.005, gamma=0.5, kernel=rbf;, score=0.682 total time=   0.1s
# [CV 1/3; 40/340] START C=0.005, gamma=0.5, kernel=linear........................
# [CV 1/3; 40/340] END C=0.005, gamma=0.5, kernel=linear;, score=0.913 total time=   0.0s
# [CV 2/3; 40/340] START C=0.005, gamma=0.5, kernel=linear........................
# [CV 2/3; 40/340] END C=0.005, gamma=0.5, kernel=linear;, score=0.841 total time=   0.0s
# [CV 3/3; 40/340] START C=0.005, gamma=0.5, kernel=linear........................
# [CV 3/3; 40/340] END C=0.005, gamma=0.5, kernel=linear;, score=0.883 total time=   0.0s
# [CV 1/3; 41/340] START C=0.01, gamma=0.002, kernel=rbf..........................
# [CV 1/3; 41/340] END C=0.01, gamma=0.002, kernel=rbf;, score=0.848 total time=   0.0s
# [CV 2/3; 41/340] START C=0.01, gamma=0.002, kernel=rbf..........................
# [CV 2/3; 41/340] END C=0.01, gamma=0.002, kernel=rbf;, score=0.635 total time=   0.0s
# [CV 3/3; 41/340] START C=0.01, gamma=0.002, kernel=rbf..........................
# [CV 3/3; 41/340] END C=0.01, gamma=0.002, kernel=rbf;, score=0.792 total time=   0.1s
# [CV 1/3; 42/340] START C=0.01, gamma=0.002, kernel=linear.......................
# [CV 1/3; 42/340] END C=0.01, gamma=0.002, kernel=linear;, score=0.928 total time=   0.0s
# [CV 2/3; 42/340] START C=0.01, gamma=0.002, kernel=linear.......................
# [CV 2/3; 42/340] END C=0.01, gamma=0.002, kernel=linear;, score=0.867 total time=   0.0s
# [CV 3/3; 42/340] START C=0.01, gamma=0.002, kernel=linear.......................
# [CV 3/3; 42/340] END C=0.01, gamma=0.002, kernel=linear;, score=0.883 total time=   0.0s
# [CV 1/3; 43/340] START C=0.01, gamma=0.003, kernel=rbf..........................
# [CV 1/3; 43/340] END C=0.01, gamma=0.003, kernel=rbf;, score=0.850 total time=   0.1s
# [CV 2/3; 43/340] START C=0.01, gamma=0.003, kernel=rbf..........................
# [CV 2/3; 43/340] END C=0.01, gamma=0.003, kernel=rbf;, score=0.613 total time=   0.1s
# [CV 3/3; 43/340] START C=0.01, gamma=0.003, kernel=rbf..........................
# [CV 3/3; 43/340] END C=0.01, gamma=0.003, kernel=rbf;, score=0.800 total time=   0.1s
# [CV 1/3; 44/340] START C=0.01, gamma=0.003, kernel=linear.......................
# [CV 1/3; 44/340] END C=0.01, gamma=0.003, kernel=linear;, score=0.928 total time=   0.0s
# [CV 2/3; 44/340] START C=0.01, gamma=0.003, kernel=linear.......................
# [CV 2/3; 44/340] END C=0.01, gamma=0.003, kernel=linear;, score=0.867 total time=   0.0s
# [CV 3/3; 44/340] START C=0.01, gamma=0.003, kernel=linear.......................
# [CV 3/3; 44/340] END C=0.01, gamma=0.003, kernel=linear;, score=0.883 total time=   0.0s
# [CV 1/3; 45/340] START C=0.01, gamma=0.004, kernel=rbf..........................
# [CV 1/3; 45/340] END C=0.01, gamma=0.004, kernel=rbf;, score=0.880 total time=   0.1s
# [CV 2/3; 45/340] START C=0.01, gamma=0.004, kernel=rbf..........................
# [CV 2/3; 45/340] END C=0.01, gamma=0.004, kernel=rbf;, score=0.614 total time=   0.1s
# [CV 3/3; 45/340] START C=0.01, gamma=0.004, kernel=rbf..........................
# [CV 3/3; 45/340] END C=0.01, gamma=0.004, kernel=rbf;, score=0.780 total time=   0.1s
# [CV 1/3; 46/340] START C=0.01, gamma=0.004, kernel=linear.......................
# [CV 1/3; 46/340] END C=0.01, gamma=0.004, kernel=linear;, score=0.928 total time=   0.0s
# [CV 2/3; 46/340] START C=0.01, gamma=0.004, kernel=linear.......................
# [CV 2/3; 46/340] END C=0.01, gamma=0.004, kernel=linear;, score=0.867 total time=   0.0s
# [CV 3/3; 46/340] START C=0.01, gamma=0.004, kernel=linear.......................
# [CV 3/3; 46/340] END C=0.01, gamma=0.004, kernel=linear;, score=0.883 total time=   0.0s
# [CV 1/3; 47/340] START C=0.01, gamma=0.001, kernel=rbf..........................
# [CV 1/3; 47/340] END C=0.01, gamma=0.001, kernel=rbf;, score=0.887 total time=   0.1s
# [CV 2/3; 47/340] START C=0.01, gamma=0.001, kernel=rbf..........................
# [CV 2/3; 47/340] END C=0.01, gamma=0.001, kernel=rbf;, score=0.670 total time=   0.0s
# [CV 3/3; 47/340] START C=0.01, gamma=0.001, kernel=rbf..........................
# [CV 3/3; 47/340] END C=0.01, gamma=0.001, kernel=rbf;, score=0.857 total time=   0.0s
# [CV 1/3; 48/340] START C=0.01, gamma=0.001, kernel=linear.......................
# [CV 1/3; 48/340] END C=0.01, gamma=0.001, kernel=linear;, score=0.928 total time=   0.0s
# [CV 2/3; 48/340] START C=0.01, gamma=0.001, kernel=linear.......................
# [CV 2/3; 48/340] END C=0.01, gamma=0.001, kernel=linear;, score=0.867 total time=   0.0s
# [CV 3/3; 48/340] START C=0.01, gamma=0.001, kernel=linear.......................
# [CV 3/3; 48/340] END C=0.01, gamma=0.001, kernel=linear;, score=0.883 total time=   0.0s
# [CV 1/3; 49/340] START C=0.01, gamma=0.005, kernel=rbf..........................
# [CV 1/3; 49/340] END C=0.01, gamma=0.005, kernel=rbf;, score=0.883 total time=   0.1s
# [CV 2/3; 49/340] START C=0.01, gamma=0.005, kernel=rbf..........................
# [CV 2/3; 49/340] END C=0.01, gamma=0.005, kernel=rbf;, score=0.628 total time=   0.1s
# [CV 3/3; 49/340] START C=0.01, gamma=0.005, kernel=rbf..........................
# [CV 3/3; 49/340] END C=0.01, gamma=0.005, kernel=rbf;, score=0.771 total time=   0.1s
# [CV 1/3; 50/340] START C=0.01, gamma=0.005, kernel=linear.......................
# [CV 1/3; 50/340] END C=0.01, gamma=0.005, kernel=linear;, score=0.928 total time=   0.0s
# [CV 2/3; 50/340] START C=0.01, gamma=0.005, kernel=linear.......................
# [CV 2/3; 50/340] END C=0.01, gamma=0.005, kernel=linear;, score=0.867 total time=   0.0s
# [CV 3/3; 50/340] START C=0.01, gamma=0.005, kernel=linear.......................
# [CV 3/3; 50/340] END C=0.01, gamma=0.005, kernel=linear;, score=0.883 total time=   0.0s
# [CV 1/3; 51/340] START C=0.01, gamma=0.01, kernel=rbf...........................
# [CV 1/3; 51/340] END C=0.01, gamma=0.01, kernel=rbf;, score=0.885 total time=   0.1s
# [CV 2/3; 51/340] START C=0.01, gamma=0.01, kernel=rbf...........................
# [CV 2/3; 51/340] END C=0.01, gamma=0.01, kernel=rbf;, score=0.610 total time=   0.1s
# [CV 3/3; 51/340] START C=0.01, gamma=0.01, kernel=rbf...........................
# [CV 3/3; 51/340] END C=0.01, gamma=0.01, kernel=rbf;, score=0.771 total time=   0.1s
# [CV 1/3; 52/340] START C=0.01, gamma=0.01, kernel=linear........................
# [CV 1/3; 52/340] END C=0.01, gamma=0.01, kernel=linear;, score=0.928 total time=   0.0s
# [CV 2/3; 52/340] START C=0.01, gamma=0.01, kernel=linear........................
# [CV 2/3; 52/340] END C=0.01, gamma=0.01, kernel=linear;, score=0.867 total time=   0.0s
# [CV 3/3; 52/340] START C=0.01, gamma=0.01, kernel=linear........................
# [CV 3/3; 52/340] END C=0.01, gamma=0.01, kernel=linear;, score=0.883 total time=   0.0s
# [CV 1/3; 53/340] START C=0.01, gamma=0.05, kernel=rbf...........................
# [CV 1/3; 53/340] END C=0.01, gamma=0.05, kernel=rbf;, score=0.864 total time=   0.1s
# [CV 2/3; 53/340] START C=0.01, gamma=0.05, kernel=rbf...........................
# [CV 2/3; 53/340] END C=0.01, gamma=0.05, kernel=rbf;, score=0.536 total time=   0.1s
# [CV 3/3; 53/340] START C=0.01, gamma=0.05, kernel=rbf...........................
# [CV 3/3; 53/340] END C=0.01, gamma=0.05, kernel=rbf;, score=0.831 total time=   0.1s
# [CV 1/3; 54/340] START C=0.01, gamma=0.05, kernel=linear........................
# [CV 1/3; 54/340] END C=0.01, gamma=0.05, kernel=linear;, score=0.928 total time=   0.0s
# [CV 2/3; 54/340] START C=0.01, gamma=0.05, kernel=linear........................
# [CV 2/3; 54/340] END C=0.01, gamma=0.05, kernel=linear;, score=0.867 total time=   0.0s
# [CV 3/3; 54/340] START C=0.01, gamma=0.05, kernel=linear........................
# [CV 3/3; 54/340] END C=0.01, gamma=0.05, kernel=linear;, score=0.883 total time=   0.0s
# [CV 1/3; 55/340] START C=0.01, gamma=0.1, kernel=rbf............................
# [CV 1/3; 55/340] END C=0.01, gamma=0.1, kernel=rbf;, score=0.832 total time=   0.1s
# [CV 2/3; 55/340] START C=0.01, gamma=0.1, kernel=rbf............................
# [CV 2/3; 55/340] END C=0.01, gamma=0.1, kernel=rbf;, score=0.571 total time=   0.1s
# [CV 3/3; 55/340] START C=0.01, gamma=0.1, kernel=rbf............................
# [CV 3/3; 55/340] END C=0.01, gamma=0.1, kernel=rbf;, score=0.785 total time=   0.1s
# [CV 1/3; 56/340] START C=0.01, gamma=0.1, kernel=linear.........................
# [CV 1/3; 56/340] END C=0.01, gamma=0.1, kernel=linear;, score=0.928 total time=   0.0s
# [CV 2/3; 56/340] START C=0.01, gamma=0.1, kernel=linear.........................
# [CV 2/3; 56/340] END C=0.01, gamma=0.1, kernel=linear;, score=0.867 total time=   0.0s
# [CV 3/3; 56/340] START C=0.01, gamma=0.1, kernel=linear.........................
# [CV 3/3; 56/340] END C=0.01, gamma=0.1, kernel=linear;, score=0.883 total time=   0.0s
# [CV 1/3; 57/340] START C=0.01, gamma=0.2, kernel=rbf............................
# [CV 1/3; 57/340] END C=0.01, gamma=0.2, kernel=rbf;, score=0.830 total time=   0.1s
# [CV 2/3; 57/340] START C=0.01, gamma=0.2, kernel=rbf............................
# [CV 2/3; 57/340] END C=0.01, gamma=0.2, kernel=rbf;, score=0.564 total time=   0.1s
# [CV 3/3; 57/340] START C=0.01, gamma=0.2, kernel=rbf............................
# [CV 3/3; 57/340] END C=0.01, gamma=0.2, kernel=rbf;, score=0.790 total time=   0.1s
# [CV 1/3; 58/340] START C=0.01, gamma=0.2, kernel=linear.........................
# [CV 1/3; 58/340] END C=0.01, gamma=0.2, kernel=linear;, score=0.928 total time=   0.0s
# [CV 2/3; 58/340] START C=0.01, gamma=0.2, kernel=linear.........................
# [CV 2/3; 58/340] END C=0.01, gamma=0.2, kernel=linear;, score=0.867 total time=   0.0s
# [CV 3/3; 58/340] START C=0.01, gamma=0.2, kernel=linear.........................
# [CV 3/3; 58/340] END C=0.01, gamma=0.2, kernel=linear;, score=0.883 total time=   0.0s
# [CV 1/3; 59/340] START C=0.01, gamma=0.5, kernel=rbf............................
# [CV 1/3; 59/340] END C=0.01, gamma=0.5, kernel=rbf;, score=0.752 total time=   0.1s
# [CV 2/3; 59/340] START C=0.01, gamma=0.5, kernel=rbf............................
# [CV 2/3; 59/340] END C=0.01, gamma=0.5, kernel=rbf;, score=0.678 total time=   0.1s
# [CV 3/3; 59/340] START C=0.01, gamma=0.5, kernel=rbf............................
# [CV 3/3; 59/340] END C=0.01, gamma=0.5, kernel=rbf;, score=0.682 total time=   0.1s
# [CV 1/3; 60/340] START C=0.01, gamma=0.5, kernel=linear.........................
# [CV 1/3; 60/340] END C=0.01, gamma=0.5, kernel=linear;, score=0.928 total time=   0.0s
# [CV 2/3; 60/340] START C=0.01, gamma=0.5, kernel=linear.........................
# [CV 2/3; 60/340] END C=0.01, gamma=0.5, kernel=linear;, score=0.867 total time=   0.0s
# [CV 3/3; 60/340] START C=0.01, gamma=0.5, kernel=linear.........................
# [CV 3/3; 60/340] END C=0.01, gamma=0.5, kernel=linear;, score=0.883 total time=   0.0s
# [CV 1/3; 61/340] START C=0.02, gamma=0.002, kernel=rbf..........................
# [CV 1/3; 61/340] END C=0.02, gamma=0.002, kernel=rbf;, score=0.838 total time=   0.1s
# [CV 2/3; 61/340] START C=0.02, gamma=0.002, kernel=rbf..........................
# [CV 2/3; 61/340] END C=0.02, gamma=0.002, kernel=rbf;, score=0.643 total time=   0.1s
# [CV 3/3; 61/340] START C=0.02, gamma=0.002, kernel=rbf..........................
# [CV 3/3; 61/340] END C=0.02, gamma=0.002, kernel=rbf;, score=0.794 total time=   0.1s
# [CV 1/3; 62/340] START C=0.02, gamma=0.002, kernel=linear.......................
# [CV 1/3; 62/340] END C=0.02, gamma=0.002, kernel=linear;, score=0.902 total time=   0.0s
# [CV 2/3; 62/340] START C=0.02, gamma=0.002, kernel=linear.......................
# [CV 2/3; 62/340] END C=0.02, gamma=0.002, kernel=linear;, score=0.895 total time=   0.0s
# [CV 3/3; 62/340] START C=0.02, gamma=0.002, kernel=linear.......................
# [CV 3/3; 62/340] END C=0.02, gamma=0.002, kernel=linear;, score=0.885 total time=   0.0s
# [CV 1/3; 63/340] START C=0.02, gamma=0.003, kernel=rbf..........................
# [CV 1/3; 63/340] END C=0.02, gamma=0.003, kernel=rbf;, score=0.849 total time=   0.1s
# [CV 2/3; 63/340] START C=0.02, gamma=0.003, kernel=rbf..........................
# [CV 2/3; 63/340] END C=0.02, gamma=0.003, kernel=rbf;, score=0.612 total time=   0.1s
# [CV 3/3; 63/340] START C=0.02, gamma=0.003, kernel=rbf..........................
# [CV 3/3; 63/340] END C=0.02, gamma=0.003, kernel=rbf;, score=0.782 total time=   0.1s
# [CV 1/3; 64/340] START C=0.02, gamma=0.003, kernel=linear.......................
# [CV 1/3; 64/340] END C=0.02, gamma=0.003, kernel=linear;, score=0.902 total time=   0.0s
# [CV 2/3; 64/340] START C=0.02, gamma=0.003, kernel=linear.......................
# [CV 2/3; 64/340] END C=0.02, gamma=0.003, kernel=linear;, score=0.895 total time=   0.0s
# [CV 3/3; 64/340] START C=0.02, gamma=0.003, kernel=linear.......................
# [CV 3/3; 64/340] END C=0.02, gamma=0.003, kernel=linear;, score=0.885 total time=   0.0s
# [CV 1/3; 65/340] START C=0.02, gamma=0.004, kernel=rbf..........................
# [CV 1/3; 65/340] END C=0.02, gamma=0.004, kernel=rbf;, score=0.874 total time=   0.1s
# [CV 2/3; 65/340] START C=0.02, gamma=0.004, kernel=rbf..........................
# [CV 2/3; 65/340] END C=0.02, gamma=0.004, kernel=rbf;, score=0.613 total time=   0.1s
# [CV 3/3; 65/340] START C=0.02, gamma=0.004, kernel=rbf..........................
# [CV 3/3; 65/340] END C=0.02, gamma=0.004, kernel=rbf;, score=0.768 total time=   0.1s
# [CV 1/3; 66/340] START C=0.02, gamma=0.004, kernel=linear.......................
# [CV 1/3; 66/340] END C=0.02, gamma=0.004, kernel=linear;, score=0.902 total time=   0.0s
# [CV 2/3; 66/340] START C=0.02, gamma=0.004, kernel=linear.......................
# [CV 2/3; 66/340] END C=0.02, gamma=0.004, kernel=linear;, score=0.895 total time=   0.0s
# [CV 3/3; 66/340] START C=0.02, gamma=0.004, kernel=linear.......................
# [CV 3/3; 66/340] END C=0.02, gamma=0.004, kernel=linear;, score=0.885 total time=   0.0s
# [CV 1/3; 67/340] START C=0.02, gamma=0.001, kernel=rbf..........................
# [CV 1/3; 67/340] END C=0.02, gamma=0.001, kernel=rbf;, score=0.890 total time=   0.1s
# [CV 2/3; 67/340] START C=0.02, gamma=0.001, kernel=rbf..........................
# [CV 2/3; 67/340] END C=0.02, gamma=0.001, kernel=rbf;, score=0.669 total time=   0.1s
# [CV 3/3; 67/340] START C=0.02, gamma=0.001, kernel=rbf..........................
# [CV 3/3; 67/340] END C=0.02, gamma=0.001, kernel=rbf;, score=0.862 total time=   0.1s
# [CV 1/3; 68/340] START C=0.02, gamma=0.001, kernel=linear.......................
# [CV 1/3; 68/340] END C=0.02, gamma=0.001, kernel=linear;, score=0.902 total time=   0.0s
# [CV 2/3; 68/340] START C=0.02, gamma=0.001, kernel=linear.......................
# [CV 2/3; 68/340] END C=0.02, gamma=0.001, kernel=linear;, score=0.895 total time=   0.0s
# [CV 3/3; 68/340] START C=0.02, gamma=0.001, kernel=linear.......................
# [CV 3/3; 68/340] END C=0.02, gamma=0.001, kernel=linear;, score=0.885 total time=   0.0s
# [CV 1/3; 69/340] START C=0.02, gamma=0.005, kernel=rbf..........................
# [CV 1/3; 69/340] END C=0.02, gamma=0.005, kernel=rbf;, score=0.881 total time=   0.1s
# [CV 2/3; 69/340] START C=0.02, gamma=0.005, kernel=rbf..........................
# [CV 2/3; 69/340] END C=0.02, gamma=0.005, kernel=rbf;, score=0.619 total time=   0.1s
# [CV 3/3; 69/340] START C=0.02, gamma=0.005, kernel=rbf..........................
# [CV 3/3; 69/340] END C=0.02, gamma=0.005, kernel=rbf;, score=0.771 total time=   0.1s
# [CV 1/3; 70/340] START C=0.02, gamma=0.005, kernel=linear.......................
# [CV 1/3; 70/340] END C=0.02, gamma=0.005, kernel=linear;, score=0.902 total time=   0.0s
# [CV 2/3; 70/340] START C=0.02, gamma=0.005, kernel=linear.......................
# [CV 2/3; 70/340] END C=0.02, gamma=0.005, kernel=linear;, score=0.895 total time=   0.0s
# [CV 3/3; 70/340] START C=0.02, gamma=0.005, kernel=linear.......................
# [CV 3/3; 70/340] END C=0.02, gamma=0.005, kernel=linear;, score=0.885 total time=   0.0s
# [CV 1/3; 71/340] START C=0.02, gamma=0.01, kernel=rbf...........................
# [CV 1/3; 71/340] END C=0.02, gamma=0.01, kernel=rbf;, score=0.885 total time=   0.1s
# [CV 2/3; 71/340] START C=0.02, gamma=0.01, kernel=rbf...........................
# [CV 2/3; 71/340] END C=0.02, gamma=0.01, kernel=rbf;, score=0.617 total time=   0.1s
# [CV 3/3; 71/340] START C=0.02, gamma=0.01, kernel=rbf...........................
# [CV 3/3; 71/340] END C=0.02, gamma=0.01, kernel=rbf;, score=0.770 total time=   0.1s
# [CV 1/3; 72/340] START C=0.02, gamma=0.01, kernel=linear........................
# [CV 1/3; 72/340] END C=0.02, gamma=0.01, kernel=linear;, score=0.902 total time=   0.0s
# [CV 2/3; 72/340] START C=0.02, gamma=0.01, kernel=linear........................
# [CV 2/3; 72/340] END C=0.02, gamma=0.01, kernel=linear;, score=0.895 total time=   0.0s
# [CV 3/3; 72/340] START C=0.02, gamma=0.01, kernel=linear........................
# [CV 3/3; 72/340] END C=0.02, gamma=0.01, kernel=linear;, score=0.885 total time=   0.0s
# [CV 1/3; 73/340] START C=0.02, gamma=0.05, kernel=rbf...........................
# [CV 1/3; 73/340] END C=0.02, gamma=0.05, kernel=rbf;, score=0.864 total time=   0.1s
# [CV 2/3; 73/340] START C=0.02, gamma=0.05, kernel=rbf...........................
# [CV 2/3; 73/340] END C=0.02, gamma=0.05, kernel=rbf;, score=0.536 total time=   0.1s
# [CV 3/3; 73/340] START C=0.02, gamma=0.05, kernel=rbf...........................
# [CV 3/3; 73/340] END C=0.02, gamma=0.05, kernel=rbf;, score=0.830 total time=   0.1s
# [CV 1/3; 74/340] START C=0.02, gamma=0.05, kernel=linear........................
# [CV 1/3; 74/340] END C=0.02, gamma=0.05, kernel=linear;, score=0.902 total time=   0.0s
# [CV 2/3; 74/340] START C=0.02, gamma=0.05, kernel=linear........................
# [CV 2/3; 74/340] END C=0.02, gamma=0.05, kernel=linear;, score=0.895 total time=   0.0s
# [CV 3/3; 74/340] START C=0.02, gamma=0.05, kernel=linear........................
# [CV 3/3; 74/340] END C=0.02, gamma=0.05, kernel=linear;, score=0.885 total time=   0.0s
# [CV 1/3; 75/340] START C=0.02, gamma=0.1, kernel=rbf............................
# [CV 1/3; 75/340] END C=0.02, gamma=0.1, kernel=rbf;, score=0.831 total time=   0.1s
# [CV 2/3; 75/340] START C=0.02, gamma=0.1, kernel=rbf............................
# [CV 2/3; 75/340] END C=0.02, gamma=0.1, kernel=rbf;, score=0.570 total time=   0.1s
# [CV 3/3; 75/340] START C=0.02, gamma=0.1, kernel=rbf............................
# [CV 3/3; 75/340] END C=0.02, gamma=0.1, kernel=rbf;, score=0.785 total time=   0.1s
# [CV 1/3; 76/340] START C=0.02, gamma=0.1, kernel=linear.........................
# [CV 1/3; 76/340] END C=0.02, gamma=0.1, kernel=linear;, score=0.902 total time=   0.0s
# [CV 2/3; 76/340] START C=0.02, gamma=0.1, kernel=linear.........................
# [CV 2/3; 76/340] END C=0.02, gamma=0.1, kernel=linear;, score=0.895 total time=   0.0s
# [CV 3/3; 76/340] START C=0.02, gamma=0.1, kernel=linear.........................
# [CV 3/3; 76/340] END C=0.02, gamma=0.1, kernel=linear;, score=0.885 total time=   0.0s
# [CV 1/3; 77/340] START C=0.02, gamma=0.2, kernel=rbf............................
# [CV 1/3; 77/340] END C=0.02, gamma=0.2, kernel=rbf;, score=0.829 total time=   0.1s
# [CV 2/3; 77/340] START C=0.02, gamma=0.2, kernel=rbf............................
# [CV 2/3; 77/340] END C=0.02, gamma=0.2, kernel=rbf;, score=0.553 total time=   0.1s
# [CV 3/3; 77/340] START C=0.02, gamma=0.2, kernel=rbf............................
# [CV 3/3; 77/340] END C=0.02, gamma=0.2, kernel=rbf;, score=0.787 total time=   0.1s
# [CV 1/3; 78/340] START C=0.02, gamma=0.2, kernel=linear.........................
# [CV 1/3; 78/340] END C=0.02, gamma=0.2, kernel=linear;, score=0.902 total time=   0.0s
# [CV 2/3; 78/340] START C=0.02, gamma=0.2, kernel=linear.........................
# [CV 2/3; 78/340] END C=0.02, gamma=0.2, kernel=linear;, score=0.895 total time=   0.0s
# [CV 3/3; 78/340] START C=0.02, gamma=0.2, kernel=linear.........................
# [CV 3/3; 78/340] END C=0.02, gamma=0.2, kernel=linear;, score=0.885 total time=   0.0s
# [CV 1/3; 79/340] START C=0.02, gamma=0.5, kernel=rbf............................
# [CV 1/3; 79/340] END C=0.02, gamma=0.5, kernel=rbf;, score=0.781 total time=   0.1s
# [CV 2/3; 79/340] START C=0.02, gamma=0.5, kernel=rbf............................
# [CV 2/3; 79/340] END C=0.02, gamma=0.5, kernel=rbf;, score=0.678 total time=   0.1s
# [CV 3/3; 79/340] START C=0.02, gamma=0.5, kernel=rbf............................
# [CV 3/3; 79/340] END C=0.02, gamma=0.5, kernel=rbf;, score=0.682 total time=   0.1s
# [CV 1/3; 80/340] START C=0.02, gamma=0.5, kernel=linear.........................
# [CV 1/3; 80/340] END C=0.02, gamma=0.5, kernel=linear;, score=0.902 total time=   0.0s
# [CV 2/3; 80/340] START C=0.02, gamma=0.5, kernel=linear.........................
# [CV 2/3; 80/340] END C=0.02, gamma=0.5, kernel=linear;, score=0.895 total time=   0.0s
# [CV 3/3; 80/340] START C=0.02, gamma=0.5, kernel=linear.........................
# [CV 3/3; 80/340] END C=0.02, gamma=0.5, kernel=linear;, score=0.885 total time=   0.0s
# [CV 1/3; 81/340] START C=0.05, gamma=0.002, kernel=rbf..........................
# [CV 1/3; 81/340] END C=0.05, gamma=0.002, kernel=rbf;, score=0.845 total time=   0.1s
# [CV 2/3; 81/340] START C=0.05, gamma=0.002, kernel=rbf..........................
# [CV 2/3; 81/340] END C=0.05, gamma=0.002, kernel=rbf;, score=0.653 total time=   0.1s
# [CV 3/3; 81/340] START C=0.05, gamma=0.002, kernel=rbf..........................
# [CV 3/3; 81/340] END C=0.05, gamma=0.002, kernel=rbf;, score=0.804 total time=   0.1s
# [CV 1/3; 82/340] START C=0.05, gamma=0.002, kernel=linear.......................
# [CV 1/3; 82/340] END C=0.05, gamma=0.002, kernel=linear;, score=0.906 total time=   0.0s
# [CV 2/3; 82/340] START C=0.05, gamma=0.002, kernel=linear.......................
# [CV 2/3; 82/340] END C=0.05, gamma=0.002, kernel=linear;, score=0.892 total time=   0.0s
# [CV 3/3; 82/340] START C=0.05, gamma=0.002, kernel=linear.......................
# [CV 3/3; 82/340] END C=0.05, gamma=0.002, kernel=linear;, score=0.854 total time=   0.0s
# [CV 1/3; 83/340] START C=0.05, gamma=0.003, kernel=rbf..........................
# [CV 1/3; 83/340] END C=0.05, gamma=0.003, kernel=rbf;, score=0.868 total time=   0.1s
# [CV 2/3; 83/340] START C=0.05, gamma=0.003, kernel=rbf..........................
# [CV 2/3; 83/340] END C=0.05, gamma=0.003, kernel=rbf;, score=0.629 total time=   0.1s
# [CV 3/3; 83/340] START C=0.05, gamma=0.003, kernel=rbf..........................
# [CV 3/3; 83/340] END C=0.05, gamma=0.003, kernel=rbf;, score=0.774 total time=   0.1s
# [CV 1/3; 84/340] START C=0.05, gamma=0.003, kernel=linear.......................
# [CV 1/3; 84/340] END C=0.05, gamma=0.003, kernel=linear;, score=0.906 total time=   0.0s
# [CV 2/3; 84/340] START C=0.05, gamma=0.003, kernel=linear.......................
# [CV 2/3; 84/340] END C=0.05, gamma=0.003, kernel=linear;, score=0.892 total time=   0.0s
# [CV 3/3; 84/340] START C=0.05, gamma=0.003, kernel=linear.......................
# [CV 3/3; 84/340] END C=0.05, gamma=0.003, kernel=linear;, score=0.854 total time=   0.0s
# [CV 1/3; 85/340] START C=0.05, gamma=0.004, kernel=rbf..........................
# [CV 1/3; 85/340] END C=0.05, gamma=0.004, kernel=rbf;, score=0.876 total time=   0.1s
# [CV 2/3; 85/340] START C=0.05, gamma=0.004, kernel=rbf..........................
# [CV 2/3; 85/340] END C=0.05, gamma=0.004, kernel=rbf;, score=0.611 total time=   0.1s
# [CV 3/3; 85/340] START C=0.05, gamma=0.004, kernel=rbf..........................
# [CV 3/3; 85/340] END C=0.05, gamma=0.004, kernel=rbf;, score=0.770 total time=   0.1s
# [CV 1/3; 86/340] START C=0.05, gamma=0.004, kernel=linear.......................
# [CV 1/3; 86/340] END C=0.05, gamma=0.004, kernel=linear;, score=0.906 total time=   0.0s
# [CV 2/3; 86/340] START C=0.05, gamma=0.004, kernel=linear.......................
# [CV 2/3; 86/340] END C=0.05, gamma=0.004, kernel=linear;, score=0.892 total time=   0.0s
# [CV 3/3; 86/340] START C=0.05, gamma=0.004, kernel=linear.......................
# [CV 3/3; 86/340] END C=0.05, gamma=0.004, kernel=linear;, score=0.854 total time=   0.0s
# [CV 1/3; 87/340] START C=0.05, gamma=0.001, kernel=rbf..........................
# [CV 1/3; 87/340] END C=0.05, gamma=0.001, kernel=rbf;, score=0.892 total time=   0.1s
# [CV 2/3; 87/340] START C=0.05, gamma=0.001, kernel=rbf..........................
# [CV 2/3; 87/340] END C=0.05, gamma=0.001, kernel=rbf;, score=0.668 total time=   0.1s
# [CV 3/3; 87/340] START C=0.05, gamma=0.001, kernel=rbf..........................
# [CV 3/3; 87/340] END C=0.05, gamma=0.001, kernel=rbf;, score=0.865 total time=   0.0s
# [CV 1/3; 88/340] START C=0.05, gamma=0.001, kernel=linear.......................
# [CV 1/3; 88/340] END C=0.05, gamma=0.001, kernel=linear;, score=0.906 total time=   0.0s
# [CV 2/3; 88/340] START C=0.05, gamma=0.001, kernel=linear.......................
# [CV 2/3; 88/340] END C=0.05, gamma=0.001, kernel=linear;, score=0.892 total time=   0.0s
# [CV 3/3; 88/340] START C=0.05, gamma=0.001, kernel=linear.......................
# [CV 3/3; 88/340] END C=0.05, gamma=0.001, kernel=linear;, score=0.854 total time=   0.0s
# [CV 1/3; 89/340] START C=0.05, gamma=0.005, kernel=rbf..........................
# [CV 1/3; 89/340] END C=0.05, gamma=0.005, kernel=rbf;, score=0.881 total time=   0.1s
# [CV 2/3; 89/340] START C=0.05, gamma=0.005, kernel=rbf..........................
# [CV 2/3; 89/340] END C=0.05, gamma=0.005, kernel=rbf;, score=0.625 total time=   0.1s
# [CV 3/3; 89/340] START C=0.05, gamma=0.005, kernel=rbf..........................
# [CV 3/3; 89/340] END C=0.05, gamma=0.005, kernel=rbf;, score=0.772 total time=   0.1s
# [CV 1/3; 90/340] START C=0.05, gamma=0.005, kernel=linear.......................
# [CV 1/3; 90/340] END C=0.05, gamma=0.005, kernel=linear;, score=0.906 total time=   0.0s
# [CV 2/3; 90/340] START C=0.05, gamma=0.005, kernel=linear.......................
# [CV 2/3; 90/340] END C=0.05, gamma=0.005, kernel=linear;, score=0.892 total time=   0.0s
# [CV 3/3; 90/340] START C=0.05, gamma=0.005, kernel=linear.......................
# [CV 3/3; 90/340] END C=0.05, gamma=0.005, kernel=linear;, score=0.854 total time=   0.0s
# [CV 1/3; 91/340] START C=0.05, gamma=0.01, kernel=rbf...........................
# [CV 1/3; 91/340] END C=0.05, gamma=0.01, kernel=rbf;, score=0.885 total time=   0.1s
# [CV 2/3; 91/340] START C=0.05, gamma=0.01, kernel=rbf...........................
# [CV 2/3; 91/340] END C=0.05, gamma=0.01, kernel=rbf;, score=0.615 total time=   0.1s
# [CV 3/3; 91/340] START C=0.05, gamma=0.01, kernel=rbf...........................
# [CV 3/3; 91/340] END C=0.05, gamma=0.01, kernel=rbf;, score=0.770 total time=   0.1s
# [CV 1/3; 92/340] START C=0.05, gamma=0.01, kernel=linear........................
# [CV 1/3; 92/340] END C=0.05, gamma=0.01, kernel=linear;, score=0.906 total time=   0.0s
# [CV 2/3; 92/340] START C=0.05, gamma=0.01, kernel=linear........................
# [CV 2/3; 92/340] END C=0.05, gamma=0.01, kernel=linear;, score=0.892 total time=   0.0s
# [CV 3/3; 92/340] START C=0.05, gamma=0.01, kernel=linear........................
# [CV 3/3; 92/340] END C=0.05, gamma=0.01, kernel=linear;, score=0.854 total time=   0.0s
# [CV 1/3; 93/340] START C=0.05, gamma=0.05, kernel=rbf...........................
# [CV 1/3; 93/340] END C=0.05, gamma=0.05, kernel=rbf;, score=0.865 total time=   0.1s
# [CV 2/3; 93/340] START C=0.05, gamma=0.05, kernel=rbf...........................
# [CV 2/3; 93/340] END C=0.05, gamma=0.05, kernel=rbf;, score=0.513 total time=   0.1s
# [CV 3/3; 93/340] START C=0.05, gamma=0.05, kernel=rbf...........................
# [CV 3/3; 93/340] END C=0.05, gamma=0.05, kernel=rbf;, score=0.835 total time=   0.1s
# [CV 1/3; 94/340] START C=0.05, gamma=0.05, kernel=linear........................
# [CV 1/3; 94/340] END C=0.05, gamma=0.05, kernel=linear;, score=0.906 total time=   0.0s
# [CV 2/3; 94/340] START C=0.05, gamma=0.05, kernel=linear........................
# [CV 2/3; 94/340] END C=0.05, gamma=0.05, kernel=linear;, score=0.892 total time=   0.0s
# [CV 3/3; 94/340] START C=0.05, gamma=0.05, kernel=linear........................
# [CV 3/3; 94/340] END C=0.05, gamma=0.05, kernel=linear;, score=0.854 total time=   0.0s
# [CV 1/3; 95/340] START C=0.05, gamma=0.1, kernel=rbf............................
# [CV 1/3; 95/340] END C=0.05, gamma=0.1, kernel=rbf;, score=0.831 total time=   0.1s
# [CV 2/3; 95/340] START C=0.05, gamma=0.1, kernel=rbf............................
# ...
# [CV 1/3; 309/340] START C=25, gamma=0.005, kernel=rbf...........................
# [CV 1/3; 309/340] END C=25, gamma=0.005, kernel=rbf;, score=0.882 total time=   0.1s
# [CV 2/3; 309/340] START C=25, gamma=0.005, kernel=rbf...........................
# [CV 2/3; 309/340] END C=25, gamma=0.005, kernel=rbf;, score=0.607 total time=   0.1s
# [CV 3/3; 309/340] START C=25, gamma=0.005, kernel=rbf...........................
# [CV 3/3; 309/340] END C=25, gamma=0.005, kernel=rbf;, score=0.835 total time=   0.1s
# [CV 1/3; 310/340] START C=25, gamma=0.005, kernel=linear........................
# [CV 1/3; 310/340] END C=25, gamma=0.005, kernel=linear;, score=0.785 total time=   0.0s
# [CV 2/3; 310/340] START C=25, gamma=0.005, kernel=linear........................
# [CV 2/3; 310/340] END C=25, gamma=0.005, kernel=linear;, score=0.895 total time=   0.0s
# [CV 3/3; 310/340] START C=25, gamma=0.005, kernel=linear........................
# [CV 3/3; 310/340] END C=25, gamma=0.005, kernel=linear;, score=0.875 total time=   0.0s
# [CV 1/3; 311/340] START C=25, gamma=0.01, kernel=rbf............................
# [CV 1/3; 311/340] END C=25, gamma=0.01, kernel=rbf;, score=0.877 total time=   0.1s
# [CV 2/3; 311/340] START C=25, gamma=0.01, kernel=rbf............................
# [CV 2/3; 311/340] END C=25, gamma=0.01, kernel=rbf;, score=0.609 total time=   0.1s
# [CV 3/3; 311/340] START C=25, gamma=0.01, kernel=rbf............................
# [CV 3/3; 311/340] END C=25, gamma=0.01, kernel=rbf;, score=0.835 total time=   0.1s
# [CV 1/3; 312/340] START C=25, gamma=0.01, kernel=linear.........................
# [CV 1/3; 312/340] END C=25, gamma=0.01, kernel=linear;, score=0.785 total time=   0.0s
# [CV 2/3; 312/340] START C=25, gamma=0.01, kernel=linear.........................
# [CV 2/3; 312/340] END C=25, gamma=0.01, kernel=linear;, score=0.895 total time=   0.0s
# [CV 3/3; 312/340] START C=25, gamma=0.01, kernel=linear.........................
# [CV 3/3; 312/340] END C=25, gamma=0.01, kernel=linear;, score=0.875 total time=   0.0s
# [CV 1/3; 313/340] START C=25, gamma=0.05, kernel=rbf............................
# [CV 1/3; 313/340] END C=25, gamma=0.05, kernel=rbf;, score=0.864 total time=   0.1s
# [CV 2/3; 313/340] START C=25, gamma=0.05, kernel=rbf............................
# [CV 2/3; 313/340] END C=25, gamma=0.05, kernel=rbf;, score=0.536 total time=   0.1s
# [CV 3/3; 313/340] START C=25, gamma=0.05, kernel=rbf............................
# [CV 3/3; 313/340] END C=25, gamma=0.05, kernel=rbf;, score=0.839 total time=   0.1s
# [CV 1/3; 314/340] START C=25, gamma=0.05, kernel=linear.........................
# [CV 1/3; 314/340] END C=25, gamma=0.05, kernel=linear;, score=0.785 total time=   0.0s
# [CV 2/3; 314/340] START C=25, gamma=0.05, kernel=linear.........................
# [CV 2/3; 314/340] END C=25, gamma=0.05, kernel=linear;, score=0.895 total time=   0.0s
# [CV 3/3; 314/340] START C=25, gamma=0.05, kernel=linear.........................
# [CV 3/3; 314/340] END C=25, gamma=0.05, kernel=linear;, score=0.875 total time=   0.0s
# [CV 1/3; 315/340] START C=25, gamma=0.1, kernel=rbf.............................
# [CV 1/3; 315/340] END C=25, gamma=0.1, kernel=rbf;, score=0.837 total time=   0.1s
# [CV 2/3; 315/340] START C=25, gamma=0.1, kernel=rbf.............................
# [CV 2/3; 315/340] END C=25, gamma=0.1, kernel=rbf;, score=0.589 total time=   0.1s
# [CV 3/3; 315/340] START C=25, gamma=0.1, kernel=rbf.............................
# [CV 3/3; 315/340] END C=25, gamma=0.1, kernel=rbf;, score=0.799 total time=   0.1s
# [CV 1/3; 316/340] START C=25, gamma=0.1, kernel=linear..........................
# [CV 1/3; 316/340] END C=25, gamma=0.1, kernel=linear;, score=0.785 total time=   0.0s
# [CV 2/3; 316/340] START C=25, gamma=0.1, kernel=linear..........................
# [CV 2/3; 316/340] END C=25, gamma=0.1, kernel=linear;, score=0.895 total time=   0.0s
# [CV 3/3; 316/340] START C=25, gamma=0.1, kernel=linear..........................
# [CV 3/3; 316/340] END C=25, gamma=0.1, kernel=linear;, score=0.875 total time=   0.0s
# [CV 1/3; 317/340] START C=25, gamma=0.2, kernel=rbf.............................
# [CV 1/3; 317/340] END C=25, gamma=0.2, kernel=rbf;, score=0.831 total time=   0.1s
# [CV 2/3; 317/340] START C=25, gamma=0.2, kernel=rbf.............................
# [CV 2/3; 317/340] END C=25, gamma=0.2, kernel=rbf;, score=0.581 total time=   0.1s
# [CV 3/3; 317/340] START C=25, gamma=0.2, kernel=rbf.............................
# [CV 3/3; 317/340] END C=25, gamma=0.2, kernel=rbf;, score=0.801 total time=   0.1s
# [CV 1/3; 318/340] START C=25, gamma=0.2, kernel=linear..........................
# [CV 1/3; 318/340] END C=25, gamma=0.2, kernel=linear;, score=0.785 total time=   0.0s
# [CV 2/3; 318/340] START C=25, gamma=0.2, kernel=linear..........................
# [CV 2/3; 318/340] END C=25, gamma=0.2, kernel=linear;, score=0.895 total time=   0.0s
# [CV 3/3; 318/340] START C=25, gamma=0.2, kernel=linear..........................
# [CV 3/3; 318/340] END C=25, gamma=0.2, kernel=linear;, score=0.875 total time=   0.0s
# [CV 1/3; 319/340] START C=25, gamma=0.5, kernel=rbf.............................
# [CV 1/3; 319/340] END C=25, gamma=0.5, kernel=rbf;, score=0.781 total time=   0.1s
# [CV 2/3; 319/340] START C=25, gamma=0.5, kernel=rbf.............................
# [CV 2/3; 319/340] END C=25, gamma=0.5, kernel=rbf;, score=0.678 total time=   0.1s
# [CV 3/3; 319/340] START C=25, gamma=0.5, kernel=rbf.............................
# [CV 3/3; 319/340] END C=25, gamma=0.5, kernel=rbf;, score=0.682 total time=   0.1s
# [CV 1/3; 320/340] START C=25, gamma=0.5, kernel=linear..........................
# [CV 1/3; 320/340] END C=25, gamma=0.5, kernel=linear;, score=0.785 total time=   0.1s
# [CV 2/3; 320/340] START C=25, gamma=0.5, kernel=linear..........................
# [CV 2/3; 320/340] END C=25, gamma=0.5, kernel=linear;, score=0.895 total time=   0.0s
# [CV 3/3; 320/340] START C=25, gamma=0.5, kernel=linear..........................
# [CV 3/3; 320/340] END C=25, gamma=0.5, kernel=linear;, score=0.875 total time=   0.0s
# [CV 1/3; 321/340] START C=50, gamma=0.002, kernel=rbf...........................
# [CV 1/3; 321/340] END C=50, gamma=0.002, kernel=rbf;, score=0.882 total time=   0.1s
# [CV 2/3; 321/340] START C=50, gamma=0.002, kernel=rbf...........................
# [CV 2/3; 321/340] END C=50, gamma=0.002, kernel=rbf;, score=0.687 total time=   0.1s
# [CV 3/3; 321/340] START C=50, gamma=0.002, kernel=rbf...........................
# [CV 3/3; 321/340] END C=50, gamma=0.002, kernel=rbf;, score=0.856 total time=   0.1s
# [CV 1/3; 322/340] START C=50, gamma=0.002, kernel=linear........................
# [CV 1/3; 322/340] END C=50, gamma=0.002, kernel=linear;, score=0.793 total time=   0.1s
# [CV 2/3; 322/340] START C=50, gamma=0.002, kernel=linear........................
# [CV 2/3; 322/340] END C=50, gamma=0.002, kernel=linear;, score=0.896 total time=   0.1s
# [CV 3/3; 322/340] START C=50, gamma=0.002, kernel=linear........................
# [CV 3/3; 322/340] END C=50, gamma=0.002, kernel=linear;, score=0.875 total time=   0.0s
# [CV 1/3; 323/340] START C=50, gamma=0.003, kernel=rbf...........................
# [CV 1/3; 323/340] END C=50, gamma=0.003, kernel=rbf;, score=0.881 total time=   0.1s
# [CV 2/3; 323/340] START C=50, gamma=0.003, kernel=rbf...........................
# [CV 2/3; 323/340] END C=50, gamma=0.003, kernel=rbf;, score=0.664 total time=   0.1s
# [CV 3/3; 323/340] START C=50, gamma=0.003, kernel=rbf...........................
# [CV 3/3; 323/340] END C=50, gamma=0.003, kernel=rbf;, score=0.845 total time=   0.1s
# [CV 1/3; 324/340] START C=50, gamma=0.003, kernel=linear........................
# [CV 1/3; 324/340] END C=50, gamma=0.003, kernel=linear;, score=0.793 total time=   0.1s
# [CV 2/3; 324/340] START C=50, gamma=0.003, kernel=linear........................
# [CV 2/3; 324/340] END C=50, gamma=0.003, kernel=linear;, score=0.896 total time=   0.1s
# [CV 3/3; 324/340] START C=50, gamma=0.003, kernel=linear........................
# [CV 3/3; 324/340] END C=50, gamma=0.003, kernel=linear;, score=0.875 total time=   0.0s
# [CV 1/3; 325/340] START C=50, gamma=0.004, kernel=rbf...........................
# [CV 1/3; 325/340] END C=50, gamma=0.004, kernel=rbf;, score=0.880 total time=   0.1s
# [CV 2/3; 325/340] START C=50, gamma=0.004, kernel=rbf...........................
# [CV 2/3; 325/340] END C=50, gamma=0.004, kernel=rbf;, score=0.621 total time=   0.1s
# [CV 3/3; 325/340] START C=50, gamma=0.004, kernel=rbf...........................
# [CV 3/3; 325/340] END C=50, gamma=0.004, kernel=rbf;, score=0.838 total time=   0.1s
# [CV 1/3; 326/340] START C=50, gamma=0.004, kernel=linear........................
# [CV 1/3; 326/340] END C=50, gamma=0.004, kernel=linear;, score=0.793 total time=   0.1s
# [CV 2/3; 326/340] START C=50, gamma=0.004, kernel=linear........................
# [CV 2/3; 326/340] END C=50, gamma=0.004, kernel=linear;, score=0.896 total time=   0.1s
# [CV 3/3; 326/340] START C=50, gamma=0.004, kernel=linear........................
# [CV 3/3; 326/340] END C=50, gamma=0.004, kernel=linear;, score=0.875 total time=   0.0s
# [CV 1/3; 327/340] START C=50, gamma=0.001, kernel=rbf...........................
# [CV 1/3; 327/340] END C=50, gamma=0.001, kernel=rbf;, score=0.874 total time=   0.1s
# [CV 2/3; 327/340] START C=50, gamma=0.001, kernel=rbf...........................
# [CV 2/3; 327/340] END C=50, gamma=0.001, kernel=rbf;, score=0.845 total time=   0.1s
# [CV 3/3; 327/340] START C=50, gamma=0.001, kernel=rbf...........................
# [CV 3/3; 327/340] END C=50, gamma=0.001, kernel=rbf;, score=0.895 total time=   0.1s
# [CV 1/3; 328/340] START C=50, gamma=0.001, kernel=linear........................
# [CV 1/3; 328/340] END C=50, gamma=0.001, kernel=linear;, score=0.793 total time=   0.1s
# [CV 2/3; 328/340] START C=50, gamma=0.001, kernel=linear........................
# [CV 2/3; 328/340] END C=50, gamma=0.001, kernel=linear;, score=0.896 total time=   0.1s
# [CV 3/3; 328/340] START C=50, gamma=0.001, kernel=linear........................
# [CV 3/3; 328/340] END C=50, gamma=0.001, kernel=linear;, score=0.875 total time=   0.0s
# [CV 1/3; 329/340] START C=50, gamma=0.005, kernel=rbf...........................
# [CV 1/3; 329/340] END C=50, gamma=0.005, kernel=rbf;, score=0.882 total time=   0.1s
# [CV 2/3; 329/340] START C=50, gamma=0.005, kernel=rbf...........................
# [CV 2/3; 329/340] END C=50, gamma=0.005, kernel=rbf;, score=0.598 total time=   0.1s
# [CV 3/3; 329/340] START C=50, gamma=0.005, kernel=rbf...........................
# [CV 3/3; 329/340] END C=50, gamma=0.005, kernel=rbf;, score=0.836 total time=   0.1s
# [CV 1/3; 330/340] START C=50, gamma=0.005, kernel=linear........................
# [CV 1/3; 330/340] END C=50, gamma=0.005, kernel=linear;, score=0.793 total time=   0.1s
# [CV 2/3; 330/340] START C=50, gamma=0.005, kernel=linear........................
# [CV 2/3; 330/340] END C=50, gamma=0.005, kernel=linear;, score=0.896 total time=   0.1s
# [CV 3/3; 330/340] START C=50, gamma=0.005, kernel=linear........................
# [CV 3/3; 330/340] END C=50, gamma=0.005, kernel=linear;, score=0.875 total time=   0.0s
# [CV 1/3; 331/340] START C=50, gamma=0.01, kernel=rbf............................
# [CV 1/3; 331/340] END C=50, gamma=0.01, kernel=rbf;, score=0.877 total time=   0.1s
# [CV 2/3; 331/340] START C=50, gamma=0.01, kernel=rbf............................
# [CV 2/3; 331/340] END C=50, gamma=0.01, kernel=rbf;, score=0.609 total time=   0.1s
# [CV 3/3; 331/340] START C=50, gamma=0.01, kernel=rbf............................
# [CV 3/3; 331/340] END C=50, gamma=0.01, kernel=rbf;, score=0.835 total time=   0.1s
# [CV 1/3; 332/340] START C=50, gamma=0.01, kernel=linear.........................
# [CV 1/3; 332/340] END C=50, gamma=0.01, kernel=linear;, score=0.793 total time=   0.1s
# [CV 2/3; 332/340] START C=50, gamma=0.01, kernel=linear.........................
# [CV 2/3; 332/340] END C=50, gamma=0.01, kernel=linear;, score=0.896 total time=   0.1s
# [CV 3/3; 332/340] START C=50, gamma=0.01, kernel=linear.........................
# [CV 3/3; 332/340] END C=50, gamma=0.01, kernel=linear;, score=0.875 total time=   0.0s
# [CV 1/3; 333/340] START C=50, gamma=0.05, kernel=rbf............................
# [CV 1/3; 333/340] END C=50, gamma=0.05, kernel=rbf;, score=0.864 total time=   0.1s
# [CV 2/3; 333/340] START C=50, gamma=0.05, kernel=rbf............................
# [CV 2/3; 333/340] END C=50, gamma=0.05, kernel=rbf;, score=0.536 total time=   0.1s
# [CV 3/3; 333/340] START C=50, gamma=0.05, kernel=rbf............................
# [CV 3/3; 333/340] END C=50, gamma=0.05, kernel=rbf;, score=0.839 total time=   0.1s
# [CV 1/3; 334/340] START C=50, gamma=0.05, kernel=linear.........................
# [CV 1/3; 334/340] END C=50, gamma=0.05, kernel=linear;, score=0.793 total time=   0.1s
# [CV 2/3; 334/340] START C=50, gamma=0.05, kernel=linear.........................
# [CV 2/3; 334/340] END C=50, gamma=0.05, kernel=linear;, score=0.896 total time=   0.1s
# [CV 3/3; 334/340] START C=50, gamma=0.05, kernel=linear.........................
# [CV 3/3; 334/340] END C=50, gamma=0.05, kernel=linear;, score=0.875 total time=   0.0s
# [CV 1/3; 335/340] START C=50, gamma=0.1, kernel=rbf.............................
# [CV 1/3; 335/340] END C=50, gamma=0.1, kernel=rbf;, score=0.837 total time=   0.1s
# [CV 2/3; 335/340] START C=50, gamma=0.1, kernel=rbf.............................
# [CV 2/3; 335/340] END C=50, gamma=0.1, kernel=rbf;, score=0.589 total time=   0.1s
# [CV 3/3; 335/340] START C=50, gamma=0.1, kernel=rbf.............................
# [CV 3/3; 335/340] END C=50, gamma=0.1, kernel=rbf;, score=0.799 total time=   0.1s
# [CV 1/3; 336/340] START C=50, gamma=0.1, kernel=linear..........................
# [CV 1/3; 336/340] END C=50, gamma=0.1, kernel=linear;, score=0.793 total time=   0.1s
# [CV 2/3; 336/340] START C=50, gamma=0.1, kernel=linear..........................
# [CV 2/3; 336/340] END C=50, gamma=0.1, kernel=linear;, score=0.896 total time=   0.1s
# [CV 3/3; 336/340] START C=50, gamma=0.1, kernel=linear..........................
# [CV 3/3; 336/340] END C=50, gamma=0.1, kernel=linear;, score=0.875 total time=   0.0s
# [CV 1/3; 337/340] START C=50, gamma=0.2, kernel=rbf.............................
# [CV 1/3; 337/340] END C=50, gamma=0.2, kernel=rbf;, score=0.831 total time=   0.1s
# [CV 2/3; 337/340] START C=50, gamma=0.2, kernel=rbf.............................
# [CV 2/3; 337/340] END C=50, gamma=0.2, kernel=rbf;, score=0.581 total time=   0.1s
# [CV 3/3; 337/340] START C=50, gamma=0.2, kernel=rbf.............................
# [CV 3/3; 337/340] END C=50, gamma=0.2, kernel=rbf;, score=0.801 total time=   0.1s
# [CV 1/3; 338/340] START C=50, gamma=0.2, kernel=linear..........................
# [CV 1/3; 338/340] END C=50, gamma=0.2, kernel=linear;, score=0.793 total time=   0.1s
# [CV 2/3; 338/340] START C=50, gamma=0.2, kernel=linear..........................
# [CV 2/3; 338/340] END C=50, gamma=0.2, kernel=linear;, score=0.896 total time=   0.1s
# [CV 3/3; 338/340] START C=50, gamma=0.2, kernel=linear..........................
# [CV 3/3; 338/340] END C=50, gamma=0.2, kernel=linear;, score=0.875 total time=   0.0s
# [CV 1/3; 339/340] START C=50, gamma=0.5, kernel=rbf.............................
# [CV 1/3; 339/340] END C=50, gamma=0.5, kernel=rbf;, score=0.781 total time=   0.1s
# [CV 2/3; 339/340] START C=50, gamma=0.5, kernel=rbf.............................
# [CV 2/3; 339/340] END C=50, gamma=0.5, kernel=rbf;, score=0.678 total time=   0.1s
# [CV 3/3; 339/340] START C=50, gamma=0.5, kernel=rbf.............................
# [CV 3/3; 339/340] END C=50, gamma=0.5, kernel=rbf;, score=0.682 total time=   0.1s
# [CV 1/3; 340/340] START C=50, gamma=0.5, kernel=linear..........................
# [CV 1/3; 340/340] END C=50, gamma=0.5, kernel=linear;, score=0.793 total time=   0.1s
# [CV 2/3; 340/340] START C=50, gamma=0.5, kernel=linear..........................
# [CV 2/3; 340/340] END C=50, gamma=0.5, kernel=linear;, score=0.896 total time=   0.1s
# [CV 3/3; 340/340] START C=50, gamma=0.5, kernel=linear..........................
# [CV 3/3; 340/340] END C=50, gamma=0.5, kernel=linear;, score=0.875 total time=   0.0s

# %%
print(best_svc)
# Out:
# SVC(C=0.02, gamma=0.002, kernel='linear', random_state=42)

# %%
print_scores(y_test, y_pred_svc)
# Out:
# ROCAUC score: 0.7262
# Accuracy score: 0.8626
# F1 score: 0.5909
# Precision score: 0.7222
# Recall: 0.5

# %% [markdown]
# # SURROGATE MODEL

# %% [markdown]
# Εκπαίδευση του surrogate model (decision tree) στο train set χρησιμοποιώντας τις προβλέψεις του svm στο train set.

# %% [markdown]
# `print_scores` on training set

# %%
y_pred_train_svc = best_svc.predict(X_train)
print_scores(y_train, y_pred_train_svc)
# Out:
# ROCAUC score: 0.9391
# Accuracy score: 0.9668
# F1 score: 0.913
# Precision score: 0.9333
# Recall: 0.8936

# %%
# =================
# DecisionTree
# =================
surrogate = DecisionTreeClassifier(random_state=SEED)

score, y_pred_surrogate = run_model(surrogate, X_train, y_pred_train_svc,
    X_test, y_test.values.ravel())

# %%
print_scores(y_test, y_pred_surrogate)
# Out:
# ROCAUC score: 0.6832
# Accuracy score: 0.8168
# F1 score: 0.5
# Precision score: 0.5455
# Recall: 0.4615

# %% [markdown]
# ## Extract rules

# %%
rules = get_rules(surrogate, feature_names=feature_names, 
                  class_names=class_names)

rules
# Out:
# ['if (Gamma_GLUDC > -1.277) and (sigma_km_product2_GLUDy <= 1.472) and (sigma_km_product2_GF6PTA > -1.526) and (sigma_km_product1_PYNP2r <= 1.521) and (sigma_km_substrate2_PHETRA <= 1.732) then class: 0 (proba: 100.0%) | based on 156 samples',
#  'if (Gamma_GLUDC <= -1.277) and (sigma_km_substrate1_2OXOADPTm <= 0.494) and (sigma_km_substrate26_LMPD_s_0450_c_1_256 <= 0.398) and (sigma_km_substrate2_GK1 <= 1.581) then class: 1 (proba: 100.0%) | based on 31 samples',
#  'if (Gamma_GLUDC <= -1.277) and (sigma_km_substrate1_2OXOADPTm > 0.494) then class: 0 (proba: 100.0%) | based on 20 samples',
#  'if (Gamma_GLUDC <= -1.277) and (sigma_km_substrate1_2OXOADPTm <= 0.494) and (sigma_km_substrate26_LMPD_s_0450_c_1_256 > 0.398) then class: 0 (proba: 100.0%) | based on 6 samples',
#  'if (Gamma_GLUDC > -1.277) and (sigma_km_product2_GLUDy > 1.472) and (sigma_km_substrate1_MALtm > 0.077) then class: 0 (proba: 100.0%) | based on 5 samples',
#  'if (Gamma_GLUDC > -1.277) and (sigma_km_product2_GLUDy > 1.472) and (sigma_km_substrate1_MALtm <= 0.077) and (Gamma_ANS <= -0.458) then class: 1 (proba: 100.0%) | based on 5 samples',
#  'if (Gamma_GLUDC > -1.277) and (sigma_km_product2_GLUDy > 1.472) and (sigma_km_substrate1_MALtm <= 0.077) and (Gamma_ANS > -0.458) and (sigma_km_substrate2_TYRTRA <= 0.95) then class: 0 (proba: 100.0%) | based on 4 samples',
#  'if (Gamma_GLUDC > -1.277) and (sigma_km_product2_GLUDy <= 1.472) and (sigma_km_product2_GF6PTA <= -1.526) and (Gamma_PHEt2r > -0.569) and (sigma_km_substrate_IGPS <= 0.764) then class: 0 (proba: 100.0%) | based on 3 samples',
#  'if (Gamma_GLUDC > -1.277) and (sigma_km_product2_GLUDy <= 1.472) and (sigma_km_product2_GF6PTA <= -1.526) and (Gamma_PHEt2r <= -0.569) then class: 1 (proba: 100.0%) | based on 3 samples',
#  'if (Gamma_GLUDC > -1.277) and (sigma_km_product2_GLUDy > 1.472) and (sigma_km_substrate1_MALtm <= 0.077) and (Gamma_ANS > -0.458) and (sigma_km_substrate2_TYRTRA > 0.95) then class: 1 (proba: 100.0%) | based on 2 samples',
#  'if (Gamma_GLUDC > -1.277) and (sigma_km_product2_GLUDy <= 1.472) and (sigma_km_product2_GF6PTA > -1.526) and (sigma_km_product1_PYNP2r > 1.521) and (Gamma_TYRTA > -0.634) then class: 1 (proba: 100.0%) | based on 2 samples',
#  'if (Gamma_GLUDC > -1.277) and (sigma_km_product2_GLUDy <= 1.472) and (sigma_km_product2_GF6PTA > -1.526) and (sigma_km_product1_PYNP2r > 1.521) and (Gamma_TYRTA <= -0.634) then class: 0 (proba: 100.0%) | based on 1 samples',
#  'if (Gamma_GLUDC > -1.277) and (sigma_km_product2_GLUDy <= 1.472) and (sigma_km_product2_GF6PTA > -1.526) and (sigma_km_product1_PYNP2r <= 1.521) and (sigma_km_substrate2_PHETRA > 1.732) then class: 1 (proba: 100.0%) | based on 1 samples',
#  'if (Gamma_GLUDC > -1.277) and (sigma_km_product2_GLUDy <= 1.472) and (sigma_km_product2_GF6PTA <= -1.526) and (Gamma_PHEt2r > -0.569) and (sigma_km_substrate_IGPS > 0.764) then class: 1 (proba: 100.0%) | based on 1 samples',
#  'if (Gamma_GLUDC <= -1.277) and (sigma_km_substrate1_2OXOADPTm <= 0.494) and (sigma_km_substrate26_LMPD_s_0450_c_1_256 <= 0.398) and (sigma_km_substrate2_GK1 > 1.581) then class: 0 (proba: 100.0%) | based on 1 samples']

# %% [markdown]
# # Validation set
#
# ## Rule 1:
#
# -    'if (Gamma_GLUDC <= -1.277) and (sigma_km_substrate1_2OXOADPTm <= 0.494) and (sigma_km_substrate26_LMPD_s_0450_c_1_256 <= 0.398) and (sigma_km_substrate2_GK1 <= 1.581) then class: 1 (proba: 100.0%) | based on 31 samples',
#
# Sample from test set rows based on __Rule 1__ (_Validation set_)

# %%
index_GP = X_test[(X_test['Gamma_GLUDC'] <= -1.277) 
            & (X_test['sigma_km_substrate1_2OXOADPTm'] <= 0.494) 
            & (X_test['sigma_km_substrate26_LMPD_s_0450_c_1_256'] <= 0.398)
            & (X_test['sigma_km_substrate2_GK1'] <= 1.581)].index

len(index_GP)
# Out:
# 18

# %%
y_val = y_test.loc[index_GP]
SI_val = y_val['Stability'].value_counts()[1] / len(y_val)
print("The Stability Index on VALIDATION SET (sampled from TEST SET) is: SI =",round(SI_val, 4), "%")

print("The Stability Index on TEST SET is: SI =",round(SI_test, 4), "%")
# Out:
# The Stability Index on VALIDATION SET (sampled from TEST SET) is: SI = 0.6111 %
# The Stability Index on TEST SET is: SI = 19.8473 %

# %% [markdown]
# # Extract Rules using DecisionTree

# %%
try:
    
    # load the model from disk
    best_tree = pickle.load(open(filename+'/tuned_tree_model', 'rb'))

except FileNotFoundError:

    # ===============
    # DecisionTree
    # =================

    param_grid_tree = {
        'max_depth': [2, 3, 4, 5, 6, 7, 8, 9, 10, 20, 25, 30, 40, 50, 100],
        'min_samples_leaf': [5, 6, 7, 8, 9, 10, 15, 20, 25, 50, 100],
        'criterion': ["gini", "entropy"]
    }

    dec_tree = DecisionTreeClassifier(random_state=SEED)

    best_tree = tune_model(dec_tree, param_grid_tree, 1000, X_train, y_train.values.ravel())
    score, y_pred = run_model(best_tree, X_train, y_train.values.ravel(),
        X_test, y_test.values.ravel())

    pickle.dump(best_tree, open(filename+'/tuned_tree_model', 'wb'))
# Out:
# /home/comex/.local/lib/python3.8/site-packages/sklearn/model_selection/_search.py:306: UserWarning: The total space of parameters 330 is smaller than n_iter=1000. Running 330 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# Fitting 3 folds for each of 330 candidates, totalling 990 fits
# [CV 1/3; 1/330] START criterion=gini, max_depth=2, min_samples_leaf=5...........
# [CV 1/3; 1/330] END criterion=gini, max_depth=2, min_samples_leaf=5;, score=0.696 total time=   0.1s
# [CV 2/3; 1/330] START criterion=gini, max_depth=2, min_samples_leaf=5...........
# [CV 2/3; 1/330] END criterion=gini, max_depth=2, min_samples_leaf=5;, score=0.626 total time=   0.0s
# [CV 3/3; 1/330] START criterion=gini, max_depth=2, min_samples_leaf=5...........
# [CV 3/3; 1/330] END criterion=gini, max_depth=2, min_samples_leaf=5;, score=0.694 total time=   0.0s
# [CV 1/3; 2/330] START criterion=gini, max_depth=2, min_samples_leaf=6...........
# [CV 1/3; 2/330] END criterion=gini, max_depth=2, min_samples_leaf=6;, score=0.696 total time=   0.0s
# [CV 2/3; 2/330] START criterion=gini, max_depth=2, min_samples_leaf=6...........
# [CV 2/3; 2/330] END criterion=gini, max_depth=2, min_samples_leaf=6;, score=0.606 total time=   0.1s
# [CV 3/3; 2/330] START criterion=gini, max_depth=2, min_samples_leaf=6...........
# [CV 3/3; 2/330] END criterion=gini, max_depth=2, min_samples_leaf=6;, score=0.708 total time=   0.1s
# [CV 1/3; 3/330] START criterion=gini, max_depth=2, min_samples_leaf=7...........
# [CV 1/3; 3/330] END criterion=gini, max_depth=2, min_samples_leaf=7;, score=0.696 total time=   0.0s
# [CV 2/3; 3/330] START criterion=gini, max_depth=2, min_samples_leaf=7...........
# [CV 2/3; 3/330] END criterion=gini, max_depth=2, min_samples_leaf=7;, score=0.606 total time=   0.0s
# [CV 3/3; 3/330] START criterion=gini, max_depth=2, min_samples_leaf=7...........
# [CV 3/3; 3/330] END criterion=gini, max_depth=2, min_samples_leaf=7;, score=0.708 total time=   0.0s
# [CV 1/3; 4/330] START criterion=gini, max_depth=2, min_samples_leaf=8...........
# [CV 1/3; 4/330] END criterion=gini, max_depth=2, min_samples_leaf=8;, score=0.696 total time=   0.1s
# [CV 2/3; 4/330] START criterion=gini, max_depth=2, min_samples_leaf=8...........
# [CV 2/3; 4/330] END criterion=gini, max_depth=2, min_samples_leaf=8;, score=0.606 total time=   0.1s
# [CV 3/3; 4/330] START criterion=gini, max_depth=2, min_samples_leaf=8...........
# [CV 3/3; 4/330] END criterion=gini, max_depth=2, min_samples_leaf=8;, score=0.708 total time=   0.0s
# [CV 1/3; 5/330] START criterion=gini, max_depth=2, min_samples_leaf=9...........
# [CV 1/3; 5/330] END criterion=gini, max_depth=2, min_samples_leaf=9;, score=0.696 total time=   0.0s
# [CV 2/3; 5/330] START criterion=gini, max_depth=2, min_samples_leaf=9...........
# [CV 2/3; 5/330] END criterion=gini, max_depth=2, min_samples_leaf=9;, score=0.606 total time=   0.0s
# [CV 3/3; 5/330] START criterion=gini, max_depth=2, min_samples_leaf=9...........
# [CV 3/3; 5/330] END criterion=gini, max_depth=2, min_samples_leaf=9;, score=0.708 total time=   0.0s
# [CV 1/3; 6/330] START criterion=gini, max_depth=2, min_samples_leaf=10..........
# [CV 1/3; 6/330] END criterion=gini, max_depth=2, min_samples_leaf=10;, score=0.696 total time=   0.0s
# [CV 2/3; 6/330] START criterion=gini, max_depth=2, min_samples_leaf=10..........
# [CV 2/3; 6/330] END criterion=gini, max_depth=2, min_samples_leaf=10;, score=0.579 total time=   0.0s
# [CV 3/3; 6/330] START criterion=gini, max_depth=2, min_samples_leaf=10..........
# [CV 3/3; 6/330] END criterion=gini, max_depth=2, min_samples_leaf=10;, score=0.708 total time=   0.0s
# [CV 1/3; 7/330] START criterion=gini, max_depth=2, min_samples_leaf=15..........
# [CV 1/3; 7/330] END criterion=gini, max_depth=2, min_samples_leaf=15;, score=0.697 total time=   0.0s
# [CV 2/3; 7/330] START criterion=gini, max_depth=2, min_samples_leaf=15..........
# [CV 2/3; 7/330] END criterion=gini, max_depth=2, min_samples_leaf=15;, score=0.693 total time=   0.0s
# [CV 3/3; 7/330] START criterion=gini, max_depth=2, min_samples_leaf=15..........
# [CV 3/3; 7/330] END criterion=gini, max_depth=2, min_samples_leaf=15;, score=0.685 total time=   0.1s
# [CV 1/3; 8/330] START criterion=gini, max_depth=2, min_samples_leaf=20..........
# [CV 1/3; 8/330] END criterion=gini, max_depth=2, min_samples_leaf=20;, score=0.697 total time=   0.0s
# [CV 2/3; 8/330] START criterion=gini, max_depth=2, min_samples_leaf=20..........
# [CV 2/3; 8/330] END criterion=gini, max_depth=2, min_samples_leaf=20;, score=0.634 total time=   0.0s
# [CV 3/3; 8/330] START criterion=gini, max_depth=2, min_samples_leaf=20..........
# [CV 3/3; 8/330] END criterion=gini, max_depth=2, min_samples_leaf=20;, score=0.729 total time=   0.0s
# [CV 1/3; 9/330] START criterion=gini, max_depth=2, min_samples_leaf=25..........
# [CV 1/3; 9/330] END criterion=gini, max_depth=2, min_samples_leaf=25;, score=0.697 total time=   0.0s
# [CV 2/3; 9/330] START criterion=gini, max_depth=2, min_samples_leaf=25..........
# [CV 2/3; 9/330] END criterion=gini, max_depth=2, min_samples_leaf=25;, score=0.634 total time=   0.0s
# [CV 3/3; 9/330] START criterion=gini, max_depth=2, min_samples_leaf=25..........
# [CV 3/3; 9/330] END criterion=gini, max_depth=2, min_samples_leaf=25;, score=0.775 total time=   0.0s
# [CV 1/3; 10/330] START criterion=gini, max_depth=2, min_samples_leaf=50.........
# [CV 1/3; 10/330] END criterion=gini, max_depth=2, min_samples_leaf=50;, score=0.759 total time=   0.0s
# [CV 2/3; 10/330] START criterion=gini, max_depth=2, min_samples_leaf=50.........
# [CV 2/3; 10/330] END criterion=gini, max_depth=2, min_samples_leaf=50;, score=0.625 total time=   0.0s
# [CV 3/3; 10/330] START criterion=gini, max_depth=2, min_samples_leaf=50.........
# [CV 3/3; 10/330] END criterion=gini, max_depth=2, min_samples_leaf=50;, score=0.748 total time=   0.0s
# [CV 1/3; 11/330] START criterion=gini, max_depth=2, min_samples_leaf=100........
# [CV 1/3; 11/330] END criterion=gini, max_depth=2, min_samples_leaf=100;, score=0.500 total time=   0.0s
# [CV 2/3; 11/330] START criterion=gini, max_depth=2, min_samples_leaf=100........
# [CV 2/3; 11/330] END criterion=gini, max_depth=2, min_samples_leaf=100;, score=0.500 total time=   0.0s
# [CV 3/3; 11/330] START criterion=gini, max_depth=2, min_samples_leaf=100........
# [CV 3/3; 11/330] END criterion=gini, max_depth=2, min_samples_leaf=100;, score=0.500 total time=   0.0s
# [CV 1/3; 12/330] START criterion=gini, max_depth=3, min_samples_leaf=5..........
# [CV 1/3; 12/330] END criterion=gini, max_depth=3, min_samples_leaf=5;, score=0.751 total time=   0.1s
# [CV 2/3; 12/330] START criterion=gini, max_depth=3, min_samples_leaf=5..........
# [CV 2/3; 12/330] END criterion=gini, max_depth=3, min_samples_leaf=5;, score=0.503 total time=   0.1s
# [CV 3/3; 12/330] START criterion=gini, max_depth=3, min_samples_leaf=5..........
# [CV 3/3; 12/330] END criterion=gini, max_depth=3, min_samples_leaf=5;, score=0.618 total time=   0.1s
# [CV 1/3; 13/330] START criterion=gini, max_depth=3, min_samples_leaf=6..........
# [CV 1/3; 13/330] END criterion=gini, max_depth=3, min_samples_leaf=6;, score=0.753 total time=   0.1s
# [CV 2/3; 13/330] START criterion=gini, max_depth=3, min_samples_leaf=6..........
# [CV 2/3; 13/330] END criterion=gini, max_depth=3, min_samples_leaf=6;, score=0.625 total time=   0.1s
# [CV 3/3; 13/330] START criterion=gini, max_depth=3, min_samples_leaf=6..........
# [CV 3/3; 13/330] END criterion=gini, max_depth=3, min_samples_leaf=6;, score=0.736 total time=   0.2s
# [CV 1/3; 14/330] START criterion=gini, max_depth=3, min_samples_leaf=7..........
# [CV 1/3; 14/330] END criterion=gini, max_depth=3, min_samples_leaf=7;, score=0.753 total time=   0.1s
# [CV 2/3; 14/330] START criterion=gini, max_depth=3, min_samples_leaf=7..........
# [CV 2/3; 14/330] END criterion=gini, max_depth=3, min_samples_leaf=7;, score=0.616 total time=   0.1s
# [CV 3/3; 14/330] START criterion=gini, max_depth=3, min_samples_leaf=7..........
# [CV 3/3; 14/330] END criterion=gini, max_depth=3, min_samples_leaf=7;, score=0.736 total time=   0.1s
# [CV 1/3; 15/330] START criterion=gini, max_depth=3, min_samples_leaf=8..........
# [CV 1/3; 15/330] END criterion=gini, max_depth=3, min_samples_leaf=8;, score=0.753 total time=   0.1s
# [CV 2/3; 15/330] START criterion=gini, max_depth=3, min_samples_leaf=8..........
# [CV 2/3; 15/330] END criterion=gini, max_depth=3, min_samples_leaf=8;, score=0.622 total time=   0.1s
# [CV 3/3; 15/330] START criterion=gini, max_depth=3, min_samples_leaf=8..........
# [CV 3/3; 15/330] END criterion=gini, max_depth=3, min_samples_leaf=8;, score=0.736 total time=   0.1s
# [CV 1/3; 16/330] START criterion=gini, max_depth=3, min_samples_leaf=9..........
# [CV 1/3; 16/330] END criterion=gini, max_depth=3, min_samples_leaf=9;, score=0.753 total time=   0.1s
# [CV 2/3; 16/330] START criterion=gini, max_depth=3, min_samples_leaf=9..........
# [CV 2/3; 16/330] END criterion=gini, max_depth=3, min_samples_leaf=9;, score=0.616 total time=   0.1s
# [CV 3/3; 16/330] START criterion=gini, max_depth=3, min_samples_leaf=9..........
# [CV 3/3; 16/330] END criterion=gini, max_depth=3, min_samples_leaf=9;, score=0.749 total time=   0.1s
# [CV 1/3; 17/330] START criterion=gini, max_depth=3, min_samples_leaf=10.........
# [CV 1/3; 17/330] END criterion=gini, max_depth=3, min_samples_leaf=10;, score=0.753 total time=   0.1s
# [CV 2/3; 17/330] START criterion=gini, max_depth=3, min_samples_leaf=10.........
# [CV 2/3; 17/330] END criterion=gini, max_depth=3, min_samples_leaf=10;, score=0.648 total time=   0.1s
# [CV 3/3; 17/330] START criterion=gini, max_depth=3, min_samples_leaf=10.........
# [CV 3/3; 17/330] END criterion=gini, max_depth=3, min_samples_leaf=10;, score=0.802 total time=   0.1s
# [CV 1/3; 18/330] START criterion=gini, max_depth=3, min_samples_leaf=15.........
# [CV 1/3; 18/330] END criterion=gini, max_depth=3, min_samples_leaf=15;, score=0.588 total time=   0.1s
# [CV 2/3; 18/330] START criterion=gini, max_depth=3, min_samples_leaf=15.........
# [CV 2/3; 18/330] END criterion=gini, max_depth=3, min_samples_leaf=15;, score=0.675 total time=   0.1s
# [CV 3/3; 18/330] START criterion=gini, max_depth=3, min_samples_leaf=15.........
# [CV 3/3; 18/330] END criterion=gini, max_depth=3, min_samples_leaf=15;, score=0.790 total time=   0.1s
# [CV 1/3; 19/330] START criterion=gini, max_depth=3, min_samples_leaf=20.........
# [CV 1/3; 19/330] END criterion=gini, max_depth=3, min_samples_leaf=20;, score=0.671 total time=   0.1s
# [CV 2/3; 19/330] START criterion=gini, max_depth=3, min_samples_leaf=20.........
# [CV 2/3; 19/330] END criterion=gini, max_depth=3, min_samples_leaf=20;, score=0.657 total time=   0.1s
# [CV 3/3; 19/330] START criterion=gini, max_depth=3, min_samples_leaf=20.........
# [CV 3/3; 19/330] END criterion=gini, max_depth=3, min_samples_leaf=20;, score=0.731 total time=   0.1s
# [CV 1/3; 20/330] START criterion=gini, max_depth=3, min_samples_leaf=25.........
# [CV 1/3; 20/330] END criterion=gini, max_depth=3, min_samples_leaf=25;, score=0.700 total time=   0.0s
# [CV 2/3; 20/330] START criterion=gini, max_depth=3, min_samples_leaf=25.........
# [CV 2/3; 20/330] END criterion=gini, max_depth=3, min_samples_leaf=25;, score=0.642 total time=   0.0s
# [CV 3/3; 20/330] START criterion=gini, max_depth=3, min_samples_leaf=25.........
# [CV 3/3; 20/330] END criterion=gini, max_depth=3, min_samples_leaf=25;, score=0.803 total time=   0.1s
# [CV 1/3; 21/330] START criterion=gini, max_depth=3, min_samples_leaf=50.........
# [CV 1/3; 21/330] END criterion=gini, max_depth=3, min_samples_leaf=50;, score=0.759 total time=   0.0s
# [CV 2/3; 21/330] START criterion=gini, max_depth=3, min_samples_leaf=50.........
# [CV 2/3; 21/330] END criterion=gini, max_depth=3, min_samples_leaf=50;, score=0.625 total time=   0.0s
# [CV 3/3; 21/330] START criterion=gini, max_depth=3, min_samples_leaf=50.........
# [CV 3/3; 21/330] END criterion=gini, max_depth=3, min_samples_leaf=50;, score=0.748 total time=   0.0s
# [CV 1/3; 22/330] START criterion=gini, max_depth=3, min_samples_leaf=100........
# [CV 1/3; 22/330] END criterion=gini, max_depth=3, min_samples_leaf=100;, score=0.500 total time=   0.0s
# [CV 2/3; 22/330] START criterion=gini, max_depth=3, min_samples_leaf=100........
# [CV 2/3; 22/330] END criterion=gini, max_depth=3, min_samples_leaf=100;, score=0.500 total time=   0.0s
# [CV 3/3; 22/330] START criterion=gini, max_depth=3, min_samples_leaf=100........
# [CV 3/3; 22/330] END criterion=gini, max_depth=3, min_samples_leaf=100;, score=0.500 total time=   0.0s
# [CV 1/3; 23/330] START criterion=gini, max_depth=4, min_samples_leaf=5..........
# [CV 1/3; 23/330] END criterion=gini, max_depth=4, min_samples_leaf=5;, score=0.711 total time=   0.1s
# [CV 2/3; 23/330] START criterion=gini, max_depth=4, min_samples_leaf=5..........
# [CV 2/3; 23/330] END criterion=gini, max_depth=4, min_samples_leaf=5;, score=0.574 total time=   0.1s
# [CV 3/3; 23/330] START criterion=gini, max_depth=4, min_samples_leaf=5..........
# [CV 3/3; 23/330] END criterion=gini, max_depth=4, min_samples_leaf=5;, score=0.651 total time=   0.1s
# [CV 1/3; 24/330] START criterion=gini, max_depth=4, min_samples_leaf=6..........
# [CV 1/3; 24/330] END criterion=gini, max_depth=4, min_samples_leaf=6;, score=0.736 total time=   0.1s
# [CV 2/3; 24/330] START criterion=gini, max_depth=4, min_samples_leaf=6..........
# [CV 2/3; 24/330] END criterion=gini, max_depth=4, min_samples_leaf=6;, score=0.625 total time=   0.1s
# [CV 3/3; 24/330] START criterion=gini, max_depth=4, min_samples_leaf=6..........
# [CV 3/3; 24/330] END criterion=gini, max_depth=4, min_samples_leaf=6;, score=0.732 total time=   0.1s
# [CV 1/3; 25/330] START criterion=gini, max_depth=4, min_samples_leaf=7..........
# [CV 1/3; 25/330] END criterion=gini, max_depth=4, min_samples_leaf=7;, score=0.745 total time=   0.1s
# [CV 2/3; 25/330] START criterion=gini, max_depth=4, min_samples_leaf=7..........
# [CV 2/3; 25/330] END criterion=gini, max_depth=4, min_samples_leaf=7;, score=0.610 total time=   0.1s
# [CV 3/3; 25/330] START criterion=gini, max_depth=4, min_samples_leaf=7..........
# [CV 3/3; 25/330] END criterion=gini, max_depth=4, min_samples_leaf=7;, score=0.728 total time=   0.1s
# [CV 1/3; 26/330] START criterion=gini, max_depth=4, min_samples_leaf=8..........
# [CV 1/3; 26/330] END criterion=gini, max_depth=4, min_samples_leaf=8;, score=0.745 total time=   0.1s
# [CV 2/3; 26/330] START criterion=gini, max_depth=4, min_samples_leaf=8..........
# [CV 2/3; 26/330] END criterion=gini, max_depth=4, min_samples_leaf=8;, score=0.646 total time=   0.1s
# [CV 3/3; 26/330] START criterion=gini, max_depth=4, min_samples_leaf=8..........
# [CV 3/3; 26/330] END criterion=gini, max_depth=4, min_samples_leaf=8;, score=0.728 total time=   0.1s
# [CV 1/3; 27/330] START criterion=gini, max_depth=4, min_samples_leaf=9..........
# [CV 1/3; 27/330] END criterion=gini, max_depth=4, min_samples_leaf=9;, score=0.741 total time=   0.1s
# [CV 2/3; 27/330] START criterion=gini, max_depth=4, min_samples_leaf=9..........
# [CV 2/3; 27/330] END criterion=gini, max_depth=4, min_samples_leaf=9;, score=0.598 total time=   0.1s
# [CV 3/3; 27/330] START criterion=gini, max_depth=4, min_samples_leaf=9..........
# [CV 3/3; 27/330] END criterion=gini, max_depth=4, min_samples_leaf=9;, score=0.738 total time=   0.1s
# [CV 1/3; 28/330] START criterion=gini, max_depth=4, min_samples_leaf=10.........
# [CV 1/3; 28/330] END criterion=gini, max_depth=4, min_samples_leaf=10;, score=0.737 total time=   0.1s
# [CV 2/3; 28/330] START criterion=gini, max_depth=4, min_samples_leaf=10.........
# [CV 2/3; 28/330] END criterion=gini, max_depth=4, min_samples_leaf=10;, score=0.648 total time=   0.1s
# [CV 3/3; 28/330] START criterion=gini, max_depth=4, min_samples_leaf=10.........
# [CV 3/3; 28/330] END criterion=gini, max_depth=4, min_samples_leaf=10;, score=0.851 total time=   0.1s
# [CV 1/3; 29/330] START criterion=gini, max_depth=4, min_samples_leaf=15.........
# [CV 1/3; 29/330] END criterion=gini, max_depth=4, min_samples_leaf=15;, score=0.588 total time=   0.1s
# [CV 2/3; 29/330] START criterion=gini, max_depth=4, min_samples_leaf=15.........
# [CV 2/3; 29/330] END criterion=gini, max_depth=4, min_samples_leaf=15;, score=0.675 total time=   0.1s
# [CV 3/3; 29/330] START criterion=gini, max_depth=4, min_samples_leaf=15.........
# [CV 3/3; 29/330] END criterion=gini, max_depth=4, min_samples_leaf=15;, score=0.795 total time=   0.1s
# [CV 1/3; 30/330] START criterion=gini, max_depth=4, min_samples_leaf=20.........
# [CV 1/3; 30/330] END criterion=gini, max_depth=4, min_samples_leaf=20;, score=0.671 total time=   0.1s
# [CV 2/3; 30/330] START criterion=gini, max_depth=4, min_samples_leaf=20.........
# [CV 2/3; 30/330] END criterion=gini, max_depth=4, min_samples_leaf=20;, score=0.657 total time=   0.1s
# [CV 3/3; 30/330] START criterion=gini, max_depth=4, min_samples_leaf=20.........
# [CV 3/3; 30/330] END criterion=gini, max_depth=4, min_samples_leaf=20;, score=0.741 total time=   0.1s
# [CV 1/3; 31/330] START criterion=gini, max_depth=4, min_samples_leaf=25.........
# [CV 1/3; 31/330] END criterion=gini, max_depth=4, min_samples_leaf=25;, score=0.700 total time=   0.1s
# [CV 2/3; 31/330] START criterion=gini, max_depth=4, min_samples_leaf=25.........
# [CV 2/3; 31/330] END criterion=gini, max_depth=4, min_samples_leaf=25;, score=0.642 total time=   0.1s
# [CV 3/3; 31/330] START criterion=gini, max_depth=4, min_samples_leaf=25.........
# [CV 3/3; 31/330] END criterion=gini, max_depth=4, min_samples_leaf=25;, score=0.803 total time=   0.0s
# [CV 1/3; 32/330] START criterion=gini, max_depth=4, min_samples_leaf=50.........
# [CV 1/3; 32/330] END criterion=gini, max_depth=4, min_samples_leaf=50;, score=0.759 total time=   0.0s
# [CV 2/3; 32/330] START criterion=gini, max_depth=4, min_samples_leaf=50.........
# [CV 2/3; 32/330] END criterion=gini, max_depth=4, min_samples_leaf=50;, score=0.625 total time=   0.1s
# [CV 3/3; 32/330] START criterion=gini, max_depth=4, min_samples_leaf=50.........
# [CV 3/3; 32/330] END criterion=gini, max_depth=4, min_samples_leaf=50;, score=0.748 total time=   0.1s
# [CV 1/3; 33/330] START criterion=gini, max_depth=4, min_samples_leaf=100........
# [CV 1/3; 33/330] END criterion=gini, max_depth=4, min_samples_leaf=100;, score=0.500 total time=   0.0s
# [CV 2/3; 33/330] START criterion=gini, max_depth=4, min_samples_leaf=100........
# [CV 2/3; 33/330] END criterion=gini, max_depth=4, min_samples_leaf=100;, score=0.500 total time=   0.0s
# [CV 3/3; 33/330] START criterion=gini, max_depth=4, min_samples_leaf=100........
# [CV 3/3; 33/330] END criterion=gini, max_depth=4, min_samples_leaf=100;, score=0.500 total time=   0.0s
# [CV 1/3; 34/330] START criterion=gini, max_depth=5, min_samples_leaf=5..........
# [CV 1/3; 34/330] END criterion=gini, max_depth=5, min_samples_leaf=5;, score=0.701 total time=   0.1s
# [CV 2/3; 34/330] START criterion=gini, max_depth=5, min_samples_leaf=5..........
# [CV 2/3; 34/330] END criterion=gini, max_depth=5, min_samples_leaf=5;, score=0.574 total time=   0.1s
# [CV 3/3; 34/330] START criterion=gini, max_depth=5, min_samples_leaf=5..........
# [CV 3/3; 34/330] END criterion=gini, max_depth=5, min_samples_leaf=5;, score=0.745 total time=   0.1s
# [CV 1/3; 35/330] START criterion=gini, max_depth=5, min_samples_leaf=6..........
# [CV 1/3; 35/330] END criterion=gini, max_depth=5, min_samples_leaf=6;, score=0.728 total time=   0.1s
# [CV 2/3; 35/330] START criterion=gini, max_depth=5, min_samples_leaf=6..........
# [CV 2/3; 35/330] END criterion=gini, max_depth=5, min_samples_leaf=6;, score=0.625 total time=   0.1s
# [CV 3/3; 35/330] START criterion=gini, max_depth=5, min_samples_leaf=6..........
# [CV 3/3; 35/330] END criterion=gini, max_depth=5, min_samples_leaf=6;, score=0.717 total time=   0.1s
# [CV 1/3; 36/330] START criterion=gini, max_depth=5, min_samples_leaf=7..........
# [CV 1/3; 36/330] END criterion=gini, max_depth=5, min_samples_leaf=7;, score=0.758 total time=   0.1s
# [CV 2/3; 36/330] START criterion=gini, max_depth=5, min_samples_leaf=7..........
# [CV 2/3; 36/330] END criterion=gini, max_depth=5, min_samples_leaf=7;, score=0.610 total time=   0.1s
# [CV 3/3; 36/330] START criterion=gini, max_depth=5, min_samples_leaf=7..........
# [CV 3/3; 36/330] END criterion=gini, max_depth=5, min_samples_leaf=7;, score=0.706 total time=   0.1s
# [CV 1/3; 37/330] START criterion=gini, max_depth=5, min_samples_leaf=8..........
# [CV 1/3; 37/330] END criterion=gini, max_depth=5, min_samples_leaf=8;, score=0.726 total time=   0.1s
# [CV 2/3; 37/330] START criterion=gini, max_depth=5, min_samples_leaf=8..........
# [CV 2/3; 37/330] END criterion=gini, max_depth=5, min_samples_leaf=8;, score=0.646 total time=   0.1s
# [CV 3/3; 37/330] START criterion=gini, max_depth=5, min_samples_leaf=8..........
# [CV 3/3; 37/330] END criterion=gini, max_depth=5, min_samples_leaf=8;, score=0.740 total time=   0.1s
# [CV 1/3; 38/330] START criterion=gini, max_depth=5, min_samples_leaf=9..........
# [CV 1/3; 38/330] END criterion=gini, max_depth=5, min_samples_leaf=9;, score=0.754 total time=   0.1s
# [CV 2/3; 38/330] START criterion=gini, max_depth=5, min_samples_leaf=9..........
# [CV 2/3; 38/330] END criterion=gini, max_depth=5, min_samples_leaf=9;, score=0.598 total time=   0.1s
# [CV 3/3; 38/330] START criterion=gini, max_depth=5, min_samples_leaf=9..........
# [CV 3/3; 38/330] END criterion=gini, max_depth=5, min_samples_leaf=9;, score=0.735 total time=   0.1s
# [CV 1/3; 39/330] START criterion=gini, max_depth=5, min_samples_leaf=10.........
# [CV 1/3; 39/330] END criterion=gini, max_depth=5, min_samples_leaf=10;, score=0.776 total time=   0.1s
# [CV 2/3; 39/330] START criterion=gini, max_depth=5, min_samples_leaf=10.........
# [CV 2/3; 39/330] END criterion=gini, max_depth=5, min_samples_leaf=10;, score=0.648 total time=   0.1s
# [CV 3/3; 39/330] START criterion=gini, max_depth=5, min_samples_leaf=10.........
# [CV 3/3; 39/330] END criterion=gini, max_depth=5, min_samples_leaf=10;, score=0.851 total time=   0.1s
# [CV 1/3; 40/330] START criterion=gini, max_depth=5, min_samples_leaf=15.........
# [CV 1/3; 40/330] END criterion=gini, max_depth=5, min_samples_leaf=15;, score=0.588 total time=   0.1s
# [CV 2/3; 40/330] START criterion=gini, max_depth=5, min_samples_leaf=15.........
# [CV 2/3; 40/330] END criterion=gini, max_depth=5, min_samples_leaf=15;, score=0.675 total time=   0.1s
# [CV 3/3; 40/330] START criterion=gini, max_depth=5, min_samples_leaf=15.........
# [CV 3/3; 40/330] END criterion=gini, max_depth=5, min_samples_leaf=15;, score=0.795 total time=   0.1s
# [CV 1/3; 41/330] START criterion=gini, max_depth=5, min_samples_leaf=20.........
# [CV 1/3; 41/330] END criterion=gini, max_depth=5, min_samples_leaf=20;, score=0.671 total time=   0.1s
# [CV 2/3; 41/330] START criterion=gini, max_depth=5, min_samples_leaf=20.........
# [CV 2/3; 41/330] END criterion=gini, max_depth=5, min_samples_leaf=20;, score=0.657 total time=   0.1s
# [CV 3/3; 41/330] START criterion=gini, max_depth=5, min_samples_leaf=20.........
# [CV 3/3; 41/330] END criterion=gini, max_depth=5, min_samples_leaf=20;, score=0.741 total time=   0.1s
# [CV 1/3; 42/330] START criterion=gini, max_depth=5, min_samples_leaf=25.........
# [CV 1/3; 42/330] END criterion=gini, max_depth=5, min_samples_leaf=25;, score=0.700 total time=   0.1s
# [CV 2/3; 42/330] START criterion=gini, max_depth=5, min_samples_leaf=25.........
# [CV 2/3; 42/330] END criterion=gini, max_depth=5, min_samples_leaf=25;, score=0.642 total time=   0.0s
# [CV 3/3; 42/330] START criterion=gini, max_depth=5, min_samples_leaf=25.........
# [CV 3/3; 42/330] END criterion=gini, max_depth=5, min_samples_leaf=25;, score=0.803 total time=   0.0s
# [CV 1/3; 43/330] START criterion=gini, max_depth=5, min_samples_leaf=50.........
# [CV 1/3; 43/330] END criterion=gini, max_depth=5, min_samples_leaf=50;, score=0.759 total time=   0.0s
# [CV 2/3; 43/330] START criterion=gini, max_depth=5, min_samples_leaf=50.........
# [CV 2/3; 43/330] END criterion=gini, max_depth=5, min_samples_leaf=50;, score=0.625 total time=   0.0s
# [CV 3/3; 43/330] START criterion=gini, max_depth=5, min_samples_leaf=50.........
# [CV 3/3; 43/330] END criterion=gini, max_depth=5, min_samples_leaf=50;, score=0.748 total time=   0.0s
# [CV 1/3; 44/330] START criterion=gini, max_depth=5, min_samples_leaf=100........
# [CV 1/3; 44/330] END criterion=gini, max_depth=5, min_samples_leaf=100;, score=0.500 total time=   0.0s
# [CV 2/3; 44/330] START criterion=gini, max_depth=5, min_samples_leaf=100........
# [CV 2/3; 44/330] END criterion=gini, max_depth=5, min_samples_leaf=100;, score=0.500 total time=   0.0s
# [CV 3/3; 44/330] START criterion=gini, max_depth=5, min_samples_leaf=100........
# [CV 3/3; 44/330] END criterion=gini, max_depth=5, min_samples_leaf=100;, score=0.500 total time=   0.0s
# [CV 1/3; 45/330] START criterion=gini, max_depth=6, min_samples_leaf=5..........
# [CV 1/3; 45/330] END criterion=gini, max_depth=6, min_samples_leaf=5;, score=0.701 total time=   0.1s
# [CV 2/3; 45/330] START criterion=gini, max_depth=6, min_samples_leaf=5..........
# [CV 2/3; 45/330] END criterion=gini, max_depth=6, min_samples_leaf=5;, score=0.574 total time=   0.1s
# [CV 3/3; 45/330] START criterion=gini, max_depth=6, min_samples_leaf=5..........
# [CV 3/3; 45/330] END criterion=gini, max_depth=6, min_samples_leaf=5;, score=0.745 total time=   0.1s
# [CV 1/3; 46/330] START criterion=gini, max_depth=6, min_samples_leaf=6..........
# [CV 1/3; 46/330] END criterion=gini, max_depth=6, min_samples_leaf=6;, score=0.728 total time=   0.1s
# [CV 2/3; 46/330] START criterion=gini, max_depth=6, min_samples_leaf=6..........
# [CV 2/3; 46/330] END criterion=gini, max_depth=6, min_samples_leaf=6;, score=0.625 total time=   0.1s
# [CV 3/3; 46/330] START criterion=gini, max_depth=6, min_samples_leaf=6..........
# [CV 3/3; 46/330] END criterion=gini, max_depth=6, min_samples_leaf=6;, score=0.717 total time=   0.1s
# [CV 1/3; 47/330] START criterion=gini, max_depth=6, min_samples_leaf=7..........
# [CV 1/3; 47/330] END criterion=gini, max_depth=6, min_samples_leaf=7;, score=0.758 total time=   0.1s
# [CV 2/3; 47/330] START criterion=gini, max_depth=6, min_samples_leaf=7..........
# [CV 2/3; 47/330] END criterion=gini, max_depth=6, min_samples_leaf=7;, score=0.610 total time=   0.1s
# [CV 3/3; 47/330] START criterion=gini, max_depth=6, min_samples_leaf=7..........
# [CV 3/3; 47/330] END criterion=gini, max_depth=6, min_samples_leaf=7;, score=0.706 total time=   0.1s
# [CV 1/3; 48/330] START criterion=gini, max_depth=6, min_samples_leaf=8..........
# [CV 1/3; 48/330] END criterion=gini, max_depth=6, min_samples_leaf=8;, score=0.726 total time=   0.1s
# [CV 2/3; 48/330] START criterion=gini, max_depth=6, min_samples_leaf=8..........
# [CV 2/3; 48/330] END criterion=gini, max_depth=6, min_samples_leaf=8;, score=0.646 total time=   0.1s
# [CV 3/3; 48/330] START criterion=gini, max_depth=6, min_samples_leaf=8..........
# [CV 3/3; 48/330] END criterion=gini, max_depth=6, min_samples_leaf=8;, score=0.740 total time=   0.1s
# [CV 1/3; 49/330] START criterion=gini, max_depth=6, min_samples_leaf=9..........
# [CV 1/3; 49/330] END criterion=gini, max_depth=6, min_samples_leaf=9;, score=0.754 total time=   0.1s
# [CV 2/3; 49/330] START criterion=gini, max_depth=6, min_samples_leaf=9..........
# [CV 2/3; 49/330] END criterion=gini, max_depth=6, min_samples_leaf=9;, score=0.598 total time=   0.1s
# [CV 3/3; 49/330] START criterion=gini, max_depth=6, min_samples_leaf=9..........
# [CV 3/3; 49/330] END criterion=gini, max_depth=6, min_samples_leaf=9;, score=0.735 total time=   0.1s
# [CV 1/3; 50/330] START criterion=gini, max_depth=6, min_samples_leaf=10.........
# [CV 1/3; 50/330] END criterion=gini, max_depth=6, min_samples_leaf=10;, score=0.776 total time=   0.1s
# [CV 2/3; 50/330] START criterion=gini, max_depth=6, min_samples_leaf=10.........
# [CV 2/3; 50/330] END criterion=gini, max_depth=6, min_samples_leaf=10;, score=0.648 total time=   0.1s
# [CV 3/3; 50/330] START criterion=gini, max_depth=6, min_samples_leaf=10.........
# [CV 3/3; 50/330] END criterion=gini, max_depth=6, min_samples_leaf=10;, score=0.851 total time=   0.1s
# [CV 1/3; 51/330] START criterion=gini, max_depth=6, min_samples_leaf=15.........
# [CV 1/3; 51/330] END criterion=gini, max_depth=6, min_samples_leaf=15;, score=0.588 total time=   0.1s
# [CV 2/3; 51/330] START criterion=gini, max_depth=6, min_samples_leaf=15.........
# [CV 2/3; 51/330] END criterion=gini, max_depth=6, min_samples_leaf=15;, score=0.675 total time=   0.1s
# [CV 3/3; 51/330] START criterion=gini, max_depth=6, min_samples_leaf=15.........
# [CV 3/3; 51/330] END criterion=gini, max_depth=6, min_samples_leaf=15;, score=0.795 total time=   0.1s
# [CV 1/3; 52/330] START criterion=gini, max_depth=6, min_samples_leaf=20.........
# [CV 1/3; 52/330] END criterion=gini, max_depth=6, min_samples_leaf=20;, score=0.671 total time=   0.1s
# [CV 2/3; 52/330] START criterion=gini, max_depth=6, min_samples_leaf=20.........
# [CV 2/3; 52/330] END criterion=gini, max_depth=6, min_samples_leaf=20;, score=0.657 total time=   0.1s
# [CV 3/3; 52/330] START criterion=gini, max_depth=6, min_samples_leaf=20.........
# [CV 3/3; 52/330] END criterion=gini, max_depth=6, min_samples_leaf=20;, score=0.741 total time=   0.1s
# [CV 1/3; 53/330] START criterion=gini, max_depth=6, min_samples_leaf=25.........
# [CV 1/3; 53/330] END criterion=gini, max_depth=6, min_samples_leaf=25;, score=0.700 total time=   0.1s
# [CV 2/3; 53/330] START criterion=gini, max_depth=6, min_samples_leaf=25.........
# [CV 2/3; 53/330] END criterion=gini, max_depth=6, min_samples_leaf=25;, score=0.642 total time=   0.1s
# [CV 3/3; 53/330] START criterion=gini, max_depth=6, min_samples_leaf=25.........
# [CV 3/3; 53/330] END criterion=gini, max_depth=6, min_samples_leaf=25;, score=0.803 total time=   0.1s
# [CV 1/3; 54/330] START criterion=gini, max_depth=6, min_samples_leaf=50.........
# [CV 1/3; 54/330] END criterion=gini, max_depth=6, min_samples_leaf=50;, score=0.759 total time=   0.0s
# [CV 2/3; 54/330] START criterion=gini, max_depth=6, min_samples_leaf=50.........
# [CV 2/3; 54/330] END criterion=gini, max_depth=6, min_samples_leaf=50;, score=0.625 total time=   0.0s
# [CV 3/3; 54/330] START criterion=gini, max_depth=6, min_samples_leaf=50.........
# [CV 3/3; 54/330] END criterion=gini, max_depth=6, min_samples_leaf=50;, score=0.748 total time=   0.0s
# [CV 1/3; 55/330] START criterion=gini, max_depth=6, min_samples_leaf=100........
# [CV 1/3; 55/330] END criterion=gini, max_depth=6, min_samples_leaf=100;, score=0.500 total time=   0.0s
# [CV 2/3; 55/330] START criterion=gini, max_depth=6, min_samples_leaf=100........
# [CV 2/3; 55/330] END criterion=gini, max_depth=6, min_samples_leaf=100;, score=0.500 total time=   0.0s
# [CV 3/3; 55/330] START criterion=gini, max_depth=6, min_samples_leaf=100........
# [CV 3/3; 55/330] END criterion=gini, max_depth=6, min_samples_leaf=100;, score=0.500 total time=   0.0s
# [CV 1/3; 56/330] START criterion=gini, max_depth=7, min_samples_leaf=5..........
# [CV 1/3; 56/330] END criterion=gini, max_depth=7, min_samples_leaf=5;, score=0.701 total time=   0.1s
# [CV 2/3; 56/330] START criterion=gini, max_depth=7, min_samples_leaf=5..........
# [CV 2/3; 56/330] END criterion=gini, max_depth=7, min_samples_leaf=5;, score=0.574 total time=   0.1s
# [CV 3/3; 56/330] START criterion=gini, max_depth=7, min_samples_leaf=5..........
# [CV 3/3; 56/330] END criterion=gini, max_depth=7, min_samples_leaf=5;, score=0.745 total time=   0.1s
# [CV 1/3; 57/330] START criterion=gini, max_depth=7, min_samples_leaf=6..........
# [CV 1/3; 57/330] END criterion=gini, max_depth=7, min_samples_leaf=6;, score=0.728 total time=   0.1s
# [CV 2/3; 57/330] START criterion=gini, max_depth=7, min_samples_leaf=6..........
# [CV 2/3; 57/330] END criterion=gini, max_depth=7, min_samples_leaf=6;, score=0.625 total time=   0.1s
# [CV 3/3; 57/330] START criterion=gini, max_depth=7, min_samples_leaf=6..........
# [CV 3/3; 57/330] END criterion=gini, max_depth=7, min_samples_leaf=6;, score=0.717 total time=   0.1s
# [CV 1/3; 58/330] START criterion=gini, max_depth=7, min_samples_leaf=7..........
# [CV 1/3; 58/330] END criterion=gini, max_depth=7, min_samples_leaf=7;, score=0.758 total time=   0.1s
# [CV 2/3; 58/330] START criterion=gini, max_depth=7, min_samples_leaf=7..........
# [CV 2/3; 58/330] END criterion=gini, max_depth=7, min_samples_leaf=7;, score=0.610 total time=   0.1s
# [CV 3/3; 58/330] START criterion=gini, max_depth=7, min_samples_leaf=7..........
# [CV 3/3; 58/330] END criterion=gini, max_depth=7, min_samples_leaf=7;, score=0.706 total time=   0.1s
# [CV 1/3; 59/330] START criterion=gini, max_depth=7, min_samples_leaf=8..........
# [CV 1/3; 59/330] END criterion=gini, max_depth=7, min_samples_leaf=8;, score=0.726 total time=   0.1s
# [CV 2/3; 59/330] START criterion=gini, max_depth=7, min_samples_leaf=8..........
# [CV 2/3; 59/330] END criterion=gini, max_depth=7, min_samples_leaf=8;, score=0.646 total time=   0.1s
# [CV 3/3; 59/330] START criterion=gini, max_depth=7, min_samples_leaf=8..........
# [CV 3/3; 59/330] END criterion=gini, max_depth=7, min_samples_leaf=8;, score=0.740 total time=   0.1s
# [CV 1/3; 60/330] START criterion=gini, max_depth=7, min_samples_leaf=9..........
# [CV 1/3; 60/330] END criterion=gini, max_depth=7, min_samples_leaf=9;, score=0.754 total time=   0.1s
# [CV 2/3; 60/330] START criterion=gini, max_depth=7, min_samples_leaf=9..........
# [CV 2/3; 60/330] END criterion=gini, max_depth=7, min_samples_leaf=9;, score=0.598 total time=   0.1s
# [CV 3/3; 60/330] START criterion=gini, max_depth=7, min_samples_leaf=9..........
# [CV 3/3; 60/330] END criterion=gini, max_depth=7, min_samples_leaf=9;, score=0.735 total time=   0.1s
# [CV 1/3; 61/330] START criterion=gini, max_depth=7, min_samples_leaf=10.........
# [CV 1/3; 61/330] END criterion=gini, max_depth=7, min_samples_leaf=10;, score=0.776 total time=   0.1s
# [CV 2/3; 61/330] START criterion=gini, max_depth=7, min_samples_leaf=10.........
# [CV 2/3; 61/330] END criterion=gini, max_depth=7, min_samples_leaf=10;, score=0.648 total time=   0.1s
# [CV 3/3; 61/330] START criterion=gini, max_depth=7, min_samples_leaf=10.........
# [CV 3/3; 61/330] END criterion=gini, max_depth=7, min_samples_leaf=10;, score=0.851 total time=   0.1s
# [CV 1/3; 62/330] START criterion=gini, max_depth=7, min_samples_leaf=15.........
# [CV 1/3; 62/330] END criterion=gini, max_depth=7, min_samples_leaf=15;, score=0.588 total time=   0.1s
# [CV 2/3; 62/330] START criterion=gini, max_depth=7, min_samples_leaf=15.........
# [CV 2/3; 62/330] END criterion=gini, max_depth=7, min_samples_leaf=15;, score=0.675 total time=   0.1s
# [CV 3/3; 62/330] START criterion=gini, max_depth=7, min_samples_leaf=15.........
# [CV 3/3; 62/330] END criterion=gini, max_depth=7, min_samples_leaf=15;, score=0.795 total time=   0.1s
# [CV 1/3; 63/330] START criterion=gini, max_depth=7, min_samples_leaf=20.........
# [CV 1/3; 63/330] END criterion=gini, max_depth=7, min_samples_leaf=20;, score=0.671 total time=   0.1s
# [CV 2/3; 63/330] START criterion=gini, max_depth=7, min_samples_leaf=20.........
# [CV 2/3; 63/330] END criterion=gini, max_depth=7, min_samples_leaf=20;, score=0.657 total time=   0.1s
# [CV 3/3; 63/330] START criterion=gini, max_depth=7, min_samples_leaf=20.........
# [CV 3/3; 63/330] END criterion=gini, max_depth=7, min_samples_leaf=20;, score=0.741 total time=   0.1s
# [CV 1/3; 64/330] START criterion=gini, max_depth=7, min_samples_leaf=25.........
# [CV 1/3; 64/330] END criterion=gini, max_depth=7, min_samples_leaf=25;, score=0.700 total time=   0.1s
# [CV 2/3; 64/330] START criterion=gini, max_depth=7, min_samples_leaf=25.........
# [CV 2/3; 64/330] END criterion=gini, max_depth=7, min_samples_leaf=25;, score=0.642 total time=   0.1s
# [CV 3/3; 64/330] START criterion=gini, max_depth=7, min_samples_leaf=25.........
# [CV 3/3; 64/330] END criterion=gini, max_depth=7, min_samples_leaf=25;, score=0.803 total time=   0.1s
# [CV 1/3; 65/330] START criterion=gini, max_depth=7, min_samples_leaf=50.........
# [CV 1/3; 65/330] END criterion=gini, max_depth=7, min_samples_leaf=50;, score=0.759 total time=   0.0s
# [CV 2/3; 65/330] START criterion=gini, max_depth=7, min_samples_leaf=50.........
# [CV 2/3; 65/330] END criterion=gini, max_depth=7, min_samples_leaf=50;, score=0.625 total time=   0.0s
# [CV 3/3; 65/330] START criterion=gini, max_depth=7, min_samples_leaf=50.........
# [CV 3/3; 65/330] END criterion=gini, max_depth=7, min_samples_leaf=50;, score=0.748 total time=   0.0s
# [CV 1/3; 66/330] START criterion=gini, max_depth=7, min_samples_leaf=100........
# [CV 1/3; 66/330] END criterion=gini, max_depth=7, min_samples_leaf=100;, score=0.500 total time=   0.0s
# [CV 2/3; 66/330] START criterion=gini, max_depth=7, min_samples_leaf=100........
# [CV 2/3; 66/330] END criterion=gini, max_depth=7, min_samples_leaf=100;, score=0.500 total time=   0.0s
# [CV 3/3; 66/330] START criterion=gini, max_depth=7, min_samples_leaf=100........
# [CV 3/3; 66/330] END criterion=gini, max_depth=7, min_samples_leaf=100;, score=0.500 total time=   0.0s
# [CV 1/3; 67/330] START criterion=gini, max_depth=8, min_samples_leaf=5..........
# [CV 1/3; 67/330] END criterion=gini, max_depth=8, min_samples_leaf=5;, score=0.701 total time=   0.1s
# [CV 2/3; 67/330] START criterion=gini, max_depth=8, min_samples_leaf=5..........
# [CV 2/3; 67/330] END criterion=gini, max_depth=8, min_samples_leaf=5;, score=0.574 total time=   0.1s
# [CV 3/3; 67/330] START criterion=gini, max_depth=8, min_samples_leaf=5..........
# [CV 3/3; 67/330] END criterion=gini, max_depth=8, min_samples_leaf=5;, score=0.745 total time=   0.1s
# [CV 1/3; 68/330] START criterion=gini, max_depth=8, min_samples_leaf=6..........
# [CV 1/3; 68/330] END criterion=gini, max_depth=8, min_samples_leaf=6;, score=0.728 total time=   0.1s
# [CV 2/3; 68/330] START criterion=gini, max_depth=8, min_samples_leaf=6..........
# [CV 2/3; 68/330] END criterion=gini, max_depth=8, min_samples_leaf=6;, score=0.625 total time=   0.1s
# [CV 3/3; 68/330] START criterion=gini, max_depth=8, min_samples_leaf=6..........
# [CV 3/3; 68/330] END criterion=gini, max_depth=8, min_samples_leaf=6;, score=0.717 total time=   0.1s
# [CV 1/3; 69/330] START criterion=gini, max_depth=8, min_samples_leaf=7..........
# [CV 1/3; 69/330] END criterion=gini, max_depth=8, min_samples_leaf=7;, score=0.758 total time=   0.1s
# [CV 2/3; 69/330] START criterion=gini, max_depth=8, min_samples_leaf=7..........
# [CV 2/3; 69/330] END criterion=gini, max_depth=8, min_samples_leaf=7;, score=0.610 total time=   0.1s
# [CV 3/3; 69/330] START criterion=gini, max_depth=8, min_samples_leaf=7..........
# [CV 3/3; 69/330] END criterion=gini, max_depth=8, min_samples_leaf=7;, score=0.706 total time=   0.1s
# [CV 1/3; 70/330] START criterion=gini, max_depth=8, min_samples_leaf=8..........
# [CV 1/3; 70/330] END criterion=gini, max_depth=8, min_samples_leaf=8;, score=0.726 total time=   0.1s
# [CV 2/3; 70/330] START criterion=gini, max_depth=8, min_samples_leaf=8..........
# [CV 2/3; 70/330] END criterion=gini, max_depth=8, min_samples_leaf=8;, score=0.646 total time=   0.1s
# [CV 3/3; 70/330] START criterion=gini, max_depth=8, min_samples_leaf=8..........
# [CV 3/3; 70/330] END criterion=gini, max_depth=8, min_samples_leaf=8;, score=0.740 total time=   0.1s
# [CV 1/3; 71/330] START criterion=gini, max_depth=8, min_samples_leaf=9..........
# [CV 1/3; 71/330] END criterion=gini, max_depth=8, min_samples_leaf=9;, score=0.754 total time=   0.1s
# [CV 2/3; 71/330] START criterion=gini, max_depth=8, min_samples_leaf=9..........
# [CV 2/3; 71/330] END criterion=gini, max_depth=8, min_samples_leaf=9;, score=0.598 total time=   0.1s
# [CV 3/3; 71/330] START criterion=gini, max_depth=8, min_samples_leaf=9..........
# [CV 3/3; 71/330] END criterion=gini, max_depth=8, min_samples_leaf=9;, score=0.735 total time=   0.1s
# [CV 1/3; 72/330] START criterion=gini, max_depth=8, min_samples_leaf=10.........
# [CV 1/3; 72/330] END criterion=gini, max_depth=8, min_samples_leaf=10;, score=0.776 total time=   0.1s
# [CV 2/3; 72/330] START criterion=gini, max_depth=8, min_samples_leaf=10.........
# [CV 2/3; 72/330] END criterion=gini, max_depth=8, min_samples_leaf=10;, score=0.648 total time=   0.1s
# [CV 3/3; 72/330] START criterion=gini, max_depth=8, min_samples_leaf=10.........
# [CV 3/3; 72/330] END criterion=gini, max_depth=8, min_samples_leaf=10;, score=0.851 total time=   0.1s
# [CV 1/3; 73/330] START criterion=gini, max_depth=8, min_samples_leaf=15.........
# [CV 1/3; 73/330] END criterion=gini, max_depth=8, min_samples_leaf=15;, score=0.588 total time=   0.1s
# [CV 2/3; 73/330] START criterion=gini, max_depth=8, min_samples_leaf=15.........
# [CV 2/3; 73/330] END criterion=gini, max_depth=8, min_samples_leaf=15;, score=0.675 total time=   0.1s
# [CV 3/3; 73/330] START criterion=gini, max_depth=8, min_samples_leaf=15.........
# [CV 3/3; 73/330] END criterion=gini, max_depth=8, min_samples_leaf=15;, score=0.795 total time=   0.1s
# [CV 1/3; 74/330] START criterion=gini, max_depth=8, min_samples_leaf=20.........
# [CV 1/3; 74/330] END criterion=gini, max_depth=8, min_samples_leaf=20;, score=0.671 total time=   0.1s
# [CV 2/3; 74/330] START criterion=gini, max_depth=8, min_samples_leaf=20.........
# [CV 2/3; 74/330] END criterion=gini, max_depth=8, min_samples_leaf=20;, score=0.657 total time=   0.1s
# [CV 3/3; 74/330] START criterion=gini, max_depth=8, min_samples_leaf=20.........
# [CV 3/3; 74/330] END criterion=gini, max_depth=8, min_samples_leaf=20;, score=0.741 total time=   0.1s
# [CV 1/3; 75/330] START criterion=gini, max_depth=8, min_samples_leaf=25.........
# [CV 1/3; 75/330] END criterion=gini, max_depth=8, min_samples_leaf=25;, score=0.700 total time=   0.1s
# [CV 2/3; 75/330] START criterion=gini, max_depth=8, min_samples_leaf=25.........
# [CV 2/3; 75/330] END criterion=gini, max_depth=8, min_samples_leaf=25;, score=0.642 total time=   0.1s
# [CV 3/3; 75/330] START criterion=gini, max_depth=8, min_samples_leaf=25.........
# [CV 3/3; 75/330] END criterion=gini, max_depth=8, min_samples_leaf=25;, score=0.803 total time=   0.1s
# [CV 1/3; 76/330] START criterion=gini, max_depth=8, min_samples_leaf=50.........
# [CV 1/3; 76/330] END criterion=gini, max_depth=8, min_samples_leaf=50;, score=0.759 total time=   0.0s
# [CV 2/3; 76/330] START criterion=gini, max_depth=8, min_samples_leaf=50.........
# [CV 2/3; 76/330] END criterion=gini, max_depth=8, min_samples_leaf=50;, score=0.625 total time=   0.0s
# [CV 3/3; 76/330] START criterion=gini, max_depth=8, min_samples_leaf=50.........
# [CV 3/3; 76/330] END criterion=gini, max_depth=8, min_samples_leaf=50;, score=0.748 total time=   0.0s
# [CV 1/3; 77/330] START criterion=gini, max_depth=8, min_samples_leaf=100........
# [CV 1/3; 77/330] END criterion=gini, max_depth=8, min_samples_leaf=100;, score=0.500 total time=   0.0s
# [CV 2/3; 77/330] START criterion=gini, max_depth=8, min_samples_leaf=100........
# [CV 2/3; 77/330] END criterion=gini, max_depth=8, min_samples_leaf=100;, score=0.500 total time=   0.0s
# [CV 3/3; 77/330] START criterion=gini, max_depth=8, min_samples_leaf=100........
# [CV 3/3; 77/330] END criterion=gini, max_depth=8, min_samples_leaf=100;, score=0.500 total time=   0.0s
# [CV 1/3; 78/330] START criterion=gini, max_depth=9, min_samples_leaf=5..........
# [CV 1/3; 78/330] END criterion=gini, max_depth=9, min_samples_leaf=5;, score=0.701 total time=   0.1s
# [CV 2/3; 78/330] START criterion=gini, max_depth=9, min_samples_leaf=5..........
# [CV 2/3; 78/330] END criterion=gini, max_depth=9, min_samples_leaf=5;, score=0.574 total time=   0.1s
# [CV 3/3; 78/330] START criterion=gini, max_depth=9, min_samples_leaf=5..........
# [CV 3/3; 78/330] END criterion=gini, max_depth=9, min_samples_leaf=5;, score=0.745 total time=   0.1s
# [CV 1/3; 79/330] START criterion=gini, max_depth=9, min_samples_leaf=6..........
# [CV 1/3; 79/330] END criterion=gini, max_depth=9, min_samples_leaf=6;, score=0.728 total time=   0.1s
# [CV 2/3; 79/330] START criterion=gini, max_depth=9, min_samples_leaf=6..........
# [CV 2/3; 79/330] END criterion=gini, max_depth=9, min_samples_leaf=6;, score=0.625 total time=   0.1s
# [CV 3/3; 79/330] START criterion=gini, max_depth=9, min_samples_leaf=6..........
# [CV 3/3; 79/330] END criterion=gini, max_depth=9, min_samples_leaf=6;, score=0.717 total time=   0.1s
# [CV 1/3; 80/330] START criterion=gini, max_depth=9, min_samples_leaf=7..........
# [CV 1/3; 80/330] END criterion=gini, max_depth=9, min_samples_leaf=7;, score=0.758 total time=   0.1s
# [CV 2/3; 80/330] START criterion=gini, max_depth=9, min_samples_leaf=7..........
# [CV 2/3; 80/330] END criterion=gini, max_depth=9, min_samples_leaf=7;, score=0.610 total time=   0.1s
# [CV 3/3; 80/330] START criterion=gini, max_depth=9, min_samples_leaf=7..........
# [CV 3/3; 80/330] END criterion=gini, max_depth=9, min_samples_leaf=7;, score=0.706 total time=   0.1s
# [CV 1/3; 81/330] START criterion=gini, max_depth=9, min_samples_leaf=8..........
# [CV 1/3; 81/330] END criterion=gini, max_depth=9, min_samples_leaf=8;, score=0.726 total time=   0.1s
# [CV 2/3; 81/330] START criterion=gini, max_depth=9, min_samples_leaf=8..........
# [CV 2/3; 81/330] END criterion=gini, max_depth=9, min_samples_leaf=8;, score=0.646 total time=   0.1s
# [CV 3/3; 81/330] START criterion=gini, max_depth=9, min_samples_leaf=8..........
# [CV 3/3; 81/330] END criterion=gini, max_depth=9, min_samples_leaf=8;, score=0.740 total time=   0.1s
# [CV 1/3; 82/330] START criterion=gini, max_depth=9, min_samples_leaf=9..........
# [CV 1/3; 82/330] END criterion=gini, max_depth=9, min_samples_leaf=9;, score=0.754 total time=   0.1s
# [CV 2/3; 82/330] START criterion=gini, max_depth=9, min_samples_leaf=9..........
# [CV 2/3; 82/330] END criterion=gini, max_depth=9, min_samples_leaf=9;, score=0.598 total time=   0.1s
# [CV 3/3; 82/330] START criterion=gini, max_depth=9, min_samples_leaf=9..........
# [CV 3/3; 82/330] END criterion=gini, max_depth=9, min_samples_leaf=9;, score=0.735 total time=   0.1s
# [CV 1/3; 83/330] START criterion=gini, max_depth=9, min_samples_leaf=10.........
# [CV 1/3; 83/330] END criterion=gini, max_depth=9, min_samples_leaf=10;, score=0.776 total time=   0.1s
# [CV 2/3; 83/330] START criterion=gini, max_depth=9, min_samples_leaf=10.........
# [CV 2/3; 83/330] END criterion=gini, max_depth=9, min_samples_leaf=10;, score=0.648 total time=   0.1s
# [CV 3/3; 83/330] START criterion=gini, max_depth=9, min_samples_leaf=10.........
# [CV 3/3; 83/330] END criterion=gini, max_depth=9, min_samples_leaf=10;, score=0.851 total time=   0.1s
# [CV 1/3; 84/330] START criterion=gini, max_depth=9, min_samples_leaf=15.........
# [CV 1/3; 84/330] END criterion=gini, max_depth=9, min_samples_leaf=15;, score=0.588 total time=   0.1s
# [CV 2/3; 84/330] START criterion=gini, max_depth=9, min_samples_leaf=15.........
# [CV 2/3; 84/330] END criterion=gini, max_depth=9, min_samples_leaf=15;, score=0.675 total time=   0.1s
# [CV 3/3; 84/330] START criterion=gini, max_depth=9, min_samples_leaf=15.........
# [CV 3/3; 84/330] END criterion=gini, max_depth=9, min_samples_leaf=15;, score=0.795 total time=   0.1s
# [CV 1/3; 85/330] START criterion=gini, max_depth=9, min_samples_leaf=20.........
# [CV 1/3; 85/330] END criterion=gini, max_depth=9, min_samples_leaf=20;, score=0.671 total time=   0.1s
# [CV 2/3; 85/330] START criterion=gini, max_depth=9, min_samples_leaf=20.........
# [CV 2/3; 85/330] END criterion=gini, max_depth=9, min_samples_leaf=20;, score=0.657 total time=   0.1s
# [CV 3/3; 85/330] START criterion=gini, max_depth=9, min_samples_leaf=20.........
# [CV 3/3; 85/330] END criterion=gini, max_depth=9, min_samples_leaf=20;, score=0.741 total time=   0.1s
# [CV 1/3; 86/330] START criterion=gini, max_depth=9, min_samples_leaf=25.........
# [CV 1/3; 86/330] END criterion=gini, max_depth=9, min_samples_leaf=25;, score=0.700 total time=   0.1s
# [CV 2/3; 86/330] START criterion=gini, max_depth=9, min_samples_leaf=25.........
# [CV 2/3; 86/330] END criterion=gini, max_depth=9, min_samples_leaf=25;, score=0.642 total time=   0.1s
# [CV 3/3; 86/330] START criterion=gini, max_depth=9, min_samples_leaf=25.........
# [CV 3/3; 86/330] END criterion=gini, max_depth=9, min_samples_leaf=25;, score=0.803 total time=   0.1s
# [CV 1/3; 87/330] START criterion=gini, max_depth=9, min_samples_leaf=50.........
# [CV 1/3; 87/330] END criterion=gini, max_depth=9, min_samples_leaf=50;, score=0.759 total time=   0.0s
# [CV 2/3; 87/330] START criterion=gini, max_depth=9, min_samples_leaf=50.........
# ...
# [CV 3/3; 302/330] END criterion=entropy, max_depth=40, min_samples_leaf=9;, score=0.789 total time=   0.1s
# [CV 1/3; 303/330] START criterion=entropy, max_depth=40, min_samples_leaf=10....
# [CV 1/3; 303/330] END criterion=entropy, max_depth=40, min_samples_leaf=10;, score=0.737 total time=   0.1s
# [CV 2/3; 303/330] START criterion=entropy, max_depth=40, min_samples_leaf=10....
# [CV 2/3; 303/330] END criterion=entropy, max_depth=40, min_samples_leaf=10;, score=0.639 total time=   0.1s
# [CV 3/3; 303/330] START criterion=entropy, max_depth=40, min_samples_leaf=10....
# [CV 3/3; 303/330] END criterion=entropy, max_depth=40, min_samples_leaf=10;, score=0.841 total time=   0.1s
# [CV 1/3; 304/330] START criterion=entropy, max_depth=40, min_samples_leaf=15....
# [CV 1/3; 304/330] END criterion=entropy, max_depth=40, min_samples_leaf=15;, score=0.607 total time=   0.1s
# [CV 2/3; 304/330] START criterion=entropy, max_depth=40, min_samples_leaf=15....
# [CV 2/3; 304/330] END criterion=entropy, max_depth=40, min_samples_leaf=15;, score=0.605 total time=   0.1s
# [CV 3/3; 304/330] START criterion=entropy, max_depth=40, min_samples_leaf=15....
# [CV 3/3; 304/330] END criterion=entropy, max_depth=40, min_samples_leaf=15;, score=0.800 total time=   0.1s
# [CV 1/3; 305/330] START criterion=entropy, max_depth=40, min_samples_leaf=20....
# [CV 1/3; 305/330] END criterion=entropy, max_depth=40, min_samples_leaf=20;, score=0.671 total time=   0.1s
# [CV 2/3; 305/330] START criterion=entropy, max_depth=40, min_samples_leaf=20....
# [CV 2/3; 305/330] END criterion=entropy, max_depth=40, min_samples_leaf=20;, score=0.644 total time=   0.1s
# [CV 3/3; 305/330] START criterion=entropy, max_depth=40, min_samples_leaf=20....
# [CV 3/3; 305/330] END criterion=entropy, max_depth=40, min_samples_leaf=20;, score=0.766 total time=   0.1s
# [CV 1/3; 306/330] START criterion=entropy, max_depth=40, min_samples_leaf=25....
# [CV 1/3; 306/330] END criterion=entropy, max_depth=40, min_samples_leaf=25;, score=0.700 total time=   0.1s
# [CV 2/3; 306/330] START criterion=entropy, max_depth=40, min_samples_leaf=25....
# [CV 2/3; 306/330] END criterion=entropy, max_depth=40, min_samples_leaf=25;, score=0.622 total time=   0.1s
# [CV 3/3; 306/330] START criterion=entropy, max_depth=40, min_samples_leaf=25....
# [CV 3/3; 306/330] END criterion=entropy, max_depth=40, min_samples_leaf=25;, score=0.766 total time=   0.1s
# [CV 1/3; 307/330] START criterion=entropy, max_depth=40, min_samples_leaf=50....
# [CV 1/3; 307/330] END criterion=entropy, max_depth=40, min_samples_leaf=50;, score=0.707 total time=   0.0s
# [CV 2/3; 307/330] START criterion=entropy, max_depth=40, min_samples_leaf=50....
# [CV 2/3; 307/330] END criterion=entropy, max_depth=40, min_samples_leaf=50;, score=0.625 total time=   0.0s
# [CV 3/3; 307/330] START criterion=entropy, max_depth=40, min_samples_leaf=50....
# [CV 3/3; 307/330] END criterion=entropy, max_depth=40, min_samples_leaf=50;, score=0.748 total time=   0.0s
# [CV 1/3; 308/330] START criterion=entropy, max_depth=40, min_samples_leaf=100...
# [CV 1/3; 308/330] END criterion=entropy, max_depth=40, min_samples_leaf=100;, score=0.500 total time=   0.0s
# [CV 2/3; 308/330] START criterion=entropy, max_depth=40, min_samples_leaf=100...
# [CV 2/3; 308/330] END criterion=entropy, max_depth=40, min_samples_leaf=100;, score=0.500 total time=   0.0s
# [CV 3/3; 308/330] START criterion=entropy, max_depth=40, min_samples_leaf=100...
# [CV 3/3; 308/330] END criterion=entropy, max_depth=40, min_samples_leaf=100;, score=0.500 total time=   0.0s
# [CV 1/3; 309/330] START criterion=entropy, max_depth=50, min_samples_leaf=5.....
# [CV 1/3; 309/330] END criterion=entropy, max_depth=50, min_samples_leaf=5;, score=0.712 total time=   0.1s
# [CV 2/3; 309/330] START criterion=entropy, max_depth=50, min_samples_leaf=5.....
# [CV 2/3; 309/330] END criterion=entropy, max_depth=50, min_samples_leaf=5;, score=0.590 total time=   0.1s
# [CV 3/3; 309/330] START criterion=entropy, max_depth=50, min_samples_leaf=5.....
# [CV 3/3; 309/330] END criterion=entropy, max_depth=50, min_samples_leaf=5;, score=0.787 total time=   0.1s
# [CV 1/3; 310/330] START criterion=entropy, max_depth=50, min_samples_leaf=6.....
# [CV 1/3; 310/330] END criterion=entropy, max_depth=50, min_samples_leaf=6;, score=0.740 total time=   0.1s
# [CV 2/3; 310/330] START criterion=entropy, max_depth=50, min_samples_leaf=6.....
# [CV 2/3; 310/330] END criterion=entropy, max_depth=50, min_samples_leaf=6;, score=0.590 total time=   0.1s
# [CV 3/3; 310/330] START criterion=entropy, max_depth=50, min_samples_leaf=6.....
# [CV 3/3; 310/330] END criterion=entropy, max_depth=50, min_samples_leaf=6;, score=0.784 total time=   0.1s
# [CV 1/3; 311/330] START criterion=entropy, max_depth=50, min_samples_leaf=7.....
# [CV 1/3; 311/330] END criterion=entropy, max_depth=50, min_samples_leaf=7;, score=0.731 total time=   0.1s
# [CV 2/3; 311/330] START criterion=entropy, max_depth=50, min_samples_leaf=7.....
# [CV 2/3; 311/330] END criterion=entropy, max_depth=50, min_samples_leaf=7;, score=0.572 total time=   0.1s
# [CV 3/3; 311/330] START criterion=entropy, max_depth=50, min_samples_leaf=7.....
# [CV 3/3; 311/330] END criterion=entropy, max_depth=50, min_samples_leaf=7;, score=0.784 total time=   0.1s
# [CV 1/3; 312/330] START criterion=entropy, max_depth=50, min_samples_leaf=8.....
# [CV 1/3; 312/330] END criterion=entropy, max_depth=50, min_samples_leaf=8;, score=0.733 total time=   0.1s
# [CV 2/3; 312/330] START criterion=entropy, max_depth=50, min_samples_leaf=8.....
# [CV 2/3; 312/330] END criterion=entropy, max_depth=50, min_samples_leaf=8;, score=0.555 total time=   0.1s
# [CV 3/3; 312/330] START criterion=entropy, max_depth=50, min_samples_leaf=8.....
# [CV 3/3; 312/330] END criterion=entropy, max_depth=50, min_samples_leaf=8;, score=0.754 total time=   0.1s
# [CV 1/3; 313/330] START criterion=entropy, max_depth=50, min_samples_leaf=9.....
# [CV 1/3; 313/330] END criterion=entropy, max_depth=50, min_samples_leaf=9;, score=0.737 total time=   0.1s
# [CV 2/3; 313/330] START criterion=entropy, max_depth=50, min_samples_leaf=9.....
# [CV 2/3; 313/330] END criterion=entropy, max_depth=50, min_samples_leaf=9;, score=0.565 total time=   0.1s
# [CV 3/3; 313/330] START criterion=entropy, max_depth=50, min_samples_leaf=9.....
# [CV 3/3; 313/330] END criterion=entropy, max_depth=50, min_samples_leaf=9;, score=0.789 total time=   0.1s
# [CV 1/3; 314/330] START criterion=entropy, max_depth=50, min_samples_leaf=10....
# [CV 1/3; 314/330] END criterion=entropy, max_depth=50, min_samples_leaf=10;, score=0.737 total time=   0.1s
# [CV 2/3; 314/330] START criterion=entropy, max_depth=50, min_samples_leaf=10....
# [CV 2/3; 314/330] END criterion=entropy, max_depth=50, min_samples_leaf=10;, score=0.639 total time=   0.1s
# [CV 3/3; 314/330] START criterion=entropy, max_depth=50, min_samples_leaf=10....
# [CV 3/3; 314/330] END criterion=entropy, max_depth=50, min_samples_leaf=10;, score=0.841 total time=   0.1s
# [CV 1/3; 315/330] START criterion=entropy, max_depth=50, min_samples_leaf=15....
# [CV 1/3; 315/330] END criterion=entropy, max_depth=50, min_samples_leaf=15;, score=0.607 total time=   0.1s
# [CV 2/3; 315/330] START criterion=entropy, max_depth=50, min_samples_leaf=15....
# [CV 2/3; 315/330] END criterion=entropy, max_depth=50, min_samples_leaf=15;, score=0.605 total time=   0.1s
# [CV 3/3; 315/330] START criterion=entropy, max_depth=50, min_samples_leaf=15....
# [CV 3/3; 315/330] END criterion=entropy, max_depth=50, min_samples_leaf=15;, score=0.800 total time=   0.1s
# [CV 1/3; 316/330] START criterion=entropy, max_depth=50, min_samples_leaf=20....
# [CV 1/3; 316/330] END criterion=entropy, max_depth=50, min_samples_leaf=20;, score=0.671 total time=   0.1s
# [CV 2/3; 316/330] START criterion=entropy, max_depth=50, min_samples_leaf=20....
# [CV 2/3; 316/330] END criterion=entropy, max_depth=50, min_samples_leaf=20;, score=0.644 total time=   0.1s
# [CV 3/3; 316/330] START criterion=entropy, max_depth=50, min_samples_leaf=20....
# [CV 3/3; 316/330] END criterion=entropy, max_depth=50, min_samples_leaf=20;, score=0.766 total time=   0.1s
# [CV 1/3; 317/330] START criterion=entropy, max_depth=50, min_samples_leaf=25....
# [CV 1/3; 317/330] END criterion=entropy, max_depth=50, min_samples_leaf=25;, score=0.700 total time=   0.1s
# [CV 2/3; 317/330] START criterion=entropy, max_depth=50, min_samples_leaf=25....
# [CV 2/3; 317/330] END criterion=entropy, max_depth=50, min_samples_leaf=25;, score=0.622 total time=   0.1s
# [CV 3/3; 317/330] START criterion=entropy, max_depth=50, min_samples_leaf=25....
# [CV 3/3; 317/330] END criterion=entropy, max_depth=50, min_samples_leaf=25;, score=0.766 total time=   0.1s
# [CV 1/3; 318/330] START criterion=entropy, max_depth=50, min_samples_leaf=50....
# [CV 1/3; 318/330] END criterion=entropy, max_depth=50, min_samples_leaf=50;, score=0.707 total time=   0.0s
# [CV 2/3; 318/330] START criterion=entropy, max_depth=50, min_samples_leaf=50....
# [CV 2/3; 318/330] END criterion=entropy, max_depth=50, min_samples_leaf=50;, score=0.625 total time=   0.0s
# [CV 3/3; 318/330] START criterion=entropy, max_depth=50, min_samples_leaf=50....
# [CV 3/3; 318/330] END criterion=entropy, max_depth=50, min_samples_leaf=50;, score=0.748 total time=   0.0s
# [CV 1/3; 319/330] START criterion=entropy, max_depth=50, min_samples_leaf=100...
# [CV 1/3; 319/330] END criterion=entropy, max_depth=50, min_samples_leaf=100;, score=0.500 total time=   0.0s
# [CV 2/3; 319/330] START criterion=entropy, max_depth=50, min_samples_leaf=100...
# [CV 2/3; 319/330] END criterion=entropy, max_depth=50, min_samples_leaf=100;, score=0.500 total time=   0.0s
# [CV 3/3; 319/330] START criterion=entropy, max_depth=50, min_samples_leaf=100...
# [CV 3/3; 319/330] END criterion=entropy, max_depth=50, min_samples_leaf=100;, score=0.500 total time=   0.0s
# [CV 1/3; 320/330] START criterion=entropy, max_depth=100, min_samples_leaf=5....
# [CV 1/3; 320/330] END criterion=entropy, max_depth=100, min_samples_leaf=5;, score=0.712 total time=   0.1s
# [CV 2/3; 320/330] START criterion=entropy, max_depth=100, min_samples_leaf=5....
# [CV 2/3; 320/330] END criterion=entropy, max_depth=100, min_samples_leaf=5;, score=0.590 total time=   0.1s
# [CV 3/3; 320/330] START criterion=entropy, max_depth=100, min_samples_leaf=5....
# [CV 3/3; 320/330] END criterion=entropy, max_depth=100, min_samples_leaf=5;, score=0.787 total time=   0.1s
# [CV 1/3; 321/330] START criterion=entropy, max_depth=100, min_samples_leaf=6....
# [CV 1/3; 321/330] END criterion=entropy, max_depth=100, min_samples_leaf=6;, score=0.740 total time=   0.1s
# [CV 2/3; 321/330] START criterion=entropy, max_depth=100, min_samples_leaf=6....
# [CV 2/3; 321/330] END criterion=entropy, max_depth=100, min_samples_leaf=6;, score=0.590 total time=   0.1s
# [CV 3/3; 321/330] START criterion=entropy, max_depth=100, min_samples_leaf=6....
# [CV 3/3; 321/330] END criterion=entropy, max_depth=100, min_samples_leaf=6;, score=0.784 total time=   0.1s
# [CV 1/3; 322/330] START criterion=entropy, max_depth=100, min_samples_leaf=7....
# [CV 1/3; 322/330] END criterion=entropy, max_depth=100, min_samples_leaf=7;, score=0.731 total time=   0.1s
# [CV 2/3; 322/330] START criterion=entropy, max_depth=100, min_samples_leaf=7....
# [CV 2/3; 322/330] END criterion=entropy, max_depth=100, min_samples_leaf=7;, score=0.572 total time=   0.1s
# [CV 3/3; 322/330] START criterion=entropy, max_depth=100, min_samples_leaf=7....
# [CV 3/3; 322/330] END criterion=entropy, max_depth=100, min_samples_leaf=7;, score=0.784 total time=   0.1s
# [CV 1/3; 323/330] START criterion=entropy, max_depth=100, min_samples_leaf=8....
# [CV 1/3; 323/330] END criterion=entropy, max_depth=100, min_samples_leaf=8;, score=0.733 total time=   0.1s
# [CV 2/3; 323/330] START criterion=entropy, max_depth=100, min_samples_leaf=8....
# [CV 2/3; 323/330] END criterion=entropy, max_depth=100, min_samples_leaf=8;, score=0.555 total time=   0.1s
# [CV 3/3; 323/330] START criterion=entropy, max_depth=100, min_samples_leaf=8....
# [CV 3/3; 323/330] END criterion=entropy, max_depth=100, min_samples_leaf=8;, score=0.754 total time=   0.1s
# [CV 1/3; 324/330] START criterion=entropy, max_depth=100, min_samples_leaf=9....
# [CV 1/3; 324/330] END criterion=entropy, max_depth=100, min_samples_leaf=9;, score=0.737 total time=   0.1s
# [CV 2/3; 324/330] START criterion=entropy, max_depth=100, min_samples_leaf=9....
# [CV 2/3; 324/330] END criterion=entropy, max_depth=100, min_samples_leaf=9;, score=0.565 total time=   0.1s
# [CV 3/3; 324/330] START criterion=entropy, max_depth=100, min_samples_leaf=9....
# [CV 3/3; 324/330] END criterion=entropy, max_depth=100, min_samples_leaf=9;, score=0.789 total time=   0.1s
# [CV 1/3; 325/330] START criterion=entropy, max_depth=100, min_samples_leaf=10...
# [CV 1/3; 325/330] END criterion=entropy, max_depth=100, min_samples_leaf=10;, score=0.737 total time=   0.1s
# [CV 2/3; 325/330] START criterion=entropy, max_depth=100, min_samples_leaf=10...
# [CV 2/3; 325/330] END criterion=entropy, max_depth=100, min_samples_leaf=10;, score=0.639 total time=   0.1s
# [CV 3/3; 325/330] START criterion=entropy, max_depth=100, min_samples_leaf=10...
# [CV 3/3; 325/330] END criterion=entropy, max_depth=100, min_samples_leaf=10;, score=0.841 total time=   0.1s
# [CV 1/3; 326/330] START criterion=entropy, max_depth=100, min_samples_leaf=15...
# [CV 1/3; 326/330] END criterion=entropy, max_depth=100, min_samples_leaf=15;, score=0.607 total time=   0.1s
# [CV 2/3; 326/330] START criterion=entropy, max_depth=100, min_samples_leaf=15...
# [CV 2/3; 326/330] END criterion=entropy, max_depth=100, min_samples_leaf=15;, score=0.605 total time=   0.1s
# [CV 3/3; 326/330] START criterion=entropy, max_depth=100, min_samples_leaf=15...
# [CV 3/3; 326/330] END criterion=entropy, max_depth=100, min_samples_leaf=15;, score=0.800 total time=   0.1s
# [CV 1/3; 327/330] START criterion=entropy, max_depth=100, min_samples_leaf=20...
# [CV 1/3; 327/330] END criterion=entropy, max_depth=100, min_samples_leaf=20;, score=0.671 total time=   0.1s
# [CV 2/3; 327/330] START criterion=entropy, max_depth=100, min_samples_leaf=20...
# [CV 2/3; 327/330] END criterion=entropy, max_depth=100, min_samples_leaf=20;, score=0.644 total time=   0.1s
# [CV 3/3; 327/330] START criterion=entropy, max_depth=100, min_samples_leaf=20...
# [CV 3/3; 327/330] END criterion=entropy, max_depth=100, min_samples_leaf=20;, score=0.766 total time=   0.1s
# [CV 1/3; 328/330] START criterion=entropy, max_depth=100, min_samples_leaf=25...
# [CV 1/3; 328/330] END criterion=entropy, max_depth=100, min_samples_leaf=25;, score=0.700 total time=   0.1s
# [CV 2/3; 328/330] START criterion=entropy, max_depth=100, min_samples_leaf=25...
# [CV 2/3; 328/330] END criterion=entropy, max_depth=100, min_samples_leaf=25;, score=0.622 total time=   0.1s
# [CV 3/3; 328/330] START criterion=entropy, max_depth=100, min_samples_leaf=25...
# [CV 3/3; 328/330] END criterion=entropy, max_depth=100, min_samples_leaf=25;, score=0.766 total time=   0.1s
# [CV 1/3; 329/330] START criterion=entropy, max_depth=100, min_samples_leaf=50...
# [CV 1/3; 329/330] END criterion=entropy, max_depth=100, min_samples_leaf=50;, score=0.707 total time=   0.0s
# [CV 2/3; 329/330] START criterion=entropy, max_depth=100, min_samples_leaf=50...
# [CV 2/3; 329/330] END criterion=entropy, max_depth=100, min_samples_leaf=50;, score=0.625 total time=   0.0s
# [CV 3/3; 329/330] START criterion=entropy, max_depth=100, min_samples_leaf=50...
# [CV 3/3; 329/330] END criterion=entropy, max_depth=100, min_samples_leaf=50;, score=0.748 total time=   0.0s
# [CV 1/3; 330/330] START criterion=entropy, max_depth=100, min_samples_leaf=100..
# [CV 1/3; 330/330] END criterion=entropy, max_depth=100, min_samples_leaf=100;, score=0.500 total time=   0.0s
# [CV 2/3; 330/330] START criterion=entropy, max_depth=100, min_samples_leaf=100..
# [CV 2/3; 330/330] END criterion=entropy, max_depth=100, min_samples_leaf=100;, score=0.500 total time=   0.0s
# [CV 3/3; 330/330] START criterion=entropy, max_depth=100, min_samples_leaf=100..
# [CV 3/3; 330/330] END criterion=entropy, max_depth=100, min_samples_leaf=100;, score=0.500 total time=   0.0s

# %%
print(best_tree)
# Out:
# DecisionTreeClassifier(max_depth=5, min_samples_leaf=10, random_state=42)

# %%
print_scores(y_test, y_pred)
# Out:
# ROCAUC score: 0.6782
# Accuracy score: 0.8321
# F1 score: 0.5
# Precision score: 0.6111
# Recall: 0.4231

# %%
rules = get_rules(best_tree, feature_names=feature_names, 
                  class_names=class_names)

rules
# Out:
# ['if (Gamma_GLUDC > -1.277) and (sigma_km_product2_GLUDy <= 1.472) and (sigma_km_product2_GF6PTA > -1.452) and (sigma_km_product2_SUCOAACTm <= 1.395) then class: 0 (proba: 100.0%) | based on 140 samples',
#  'if (Gamma_GLUDC <= -1.277) and (sigma_km_product1_ICDHxm > 0.056) and (sigma_km_product27_LMPD_s_0450_c_1_256 <= 0.76) then class: 1 (proba: 100.0%) | based on 18 samples',
#  'if (Gamma_GLUDC > -1.277) and (sigma_km_product2_GLUDy > 1.472) then class: 0 (proba: 56.25%) | based on 16 samples',
#  'if (Gamma_GLUDC > -1.277) and (sigma_km_product2_GLUDy <= 1.472) and (sigma_km_product2_GF6PTA > -1.452) and (sigma_km_product2_SUCOAACTm > 1.395) then class: 0 (proba: 81.25%) | based on 16 samples',
#  'if (Gamma_GLUDC <= -1.277) and (sigma_km_product1_ICDHxm <= 0.056) and (sigma_km_product2_AKGMAL <= -0.354) then class: 0 (proba: 100.0%) | based on 14 samples',
#  'if (Gamma_GLUDC <= -1.277) and (sigma_km_product1_ICDHxm > 0.056) and (sigma_km_product27_LMPD_s_0450_c_1_256 > 0.76) then class: 1 (proba: 61.54%) | based on 13 samples',
#  'if (Gamma_GLUDC <= -1.277) and (sigma_km_product1_ICDHxm <= 0.056) and (sigma_km_product2_AKGMAL > -0.354) then class: 0 (proba: 53.85%) | based on 13 samples',
#  'if (Gamma_GLUDC > -1.277) and (sigma_km_product2_GLUDy <= 1.472) and (sigma_km_product2_GF6PTA <= -1.452) then class: 0 (proba: 54.55%) | based on 11 samples']

# %% [markdown]
# # Validation set
#
# ## Rule 1:
#
# -  if (Gamma_GLUDC <= -1.277) and (sigma_km_product1_ICDHxm > 0.056) and (sigma_km_product27_LMPD_s_0450_c_1_256 <= 0.76) then class: 1 (proba: 100.0%) | based on 18 samples'
#
#
# Sample from test set rows based on __Rule 1__ (_Validation set_)

# %%
index_GP = X_test[(X_test['Gamma_GLUDC'] <= -1.277) 
                  & (X_test['sigma_km_product1_ICDHxm'] > 0.056)
                  & (X_test['sigma_km_product27_LMPD_s_0450_c_1_256'] <= 0.76)].index

len(index_GP)
# Out:
# 8

# %%
y_val = y_test.loc[index_GP]
SI_val = y_val['Stability'].value_counts()[1] / len(y_val)
print("The Stability Index on VALIDATION SET (sampled from TEST SET) is: SI =",round(SI_val, 4), "%")

print("The Stability Index on TEST SET is: SI =",round(SI_test, 4), "%")
# Out:
# The Stability Index on VALIDATION SET (sampled from TEST SET) is: SI = 0.625 %
# The Stability Index on TEST SET is: SI = 19.8473 %

# %% [markdown]
# # SCOPE-RULES

# %%
# Import skope-rules
import six
import sys

sys.modules['sklearn.externals.six'] = six
from skrules import SkopeRules

# %%
# Train a skope-rules-boosting classifier
skope_rules_clf = SkopeRules(feature_names=feature_names, 
                             random_state=SEED,
                             # max_features='auto',
                             n_estimators=30,
                             recall_min=0.05, precision_min=0.9,
                             max_samples=0.7,
                             max_depth_duplication= 4, 
                             max_depth = 5, 
                             verbose=2)

skope_rules_clf.fit(X_train.values, y_train.values.reshape(-1,))
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Building estimator 1 of 30 for this parallel run (total 30)...
# Building estimator 2 of 30 for this parallel run (total 30)...
# Building estimator 3 of 30 for this parallel run (total 30)...
# Building estimator 4 of 30 for this parallel run (total 30)...
# Building estimator 5 of 30 for this parallel run (total 30)...
# Building estimator 6 of 30 for this parallel run (total 30)...
# Building estimator 7 of 30 for this parallel run (total 30)...
# Building estimator 8 of 30 for this parallel run (total 30)...
# Building estimator 9 of 30 for this parallel run (total 30)...
# Building estimator 10 of 30 for this parallel run (total 30)...
# Building estimator 11 of 30 for this parallel run (total 30)...
# Building estimator 12 of 30 for this parallel run (total 30)...
# Building estimator 13 of 30 for this parallel run (total 30)...
# Building estimator 14 of 30 for this parallel run (total 30)...
# Building estimator 15 of 30 for this parallel run (total 30)...
# Building estimator 16 of 30 for this parallel run (total 30)...
# Building estimator 17 of 30 for this parallel run (total 30)...
# Building estimator 18 of 30 for this parallel run (total 30)...
# Building estimator 19 of 30 for this parallel run (total 30)...
# Building estimator 20 of 30 for this parallel run (total 30)...
# Building estimator 21 of 30 for this parallel run (total 30)...
# Building estimator 22 of 30 for this parallel run (total 30)...
# Building estimator 23 of 30 for this parallel run (total 30)...
# Building estimator 24 of 30 for this parallel run (total 30)...
# Building estimator 25 of 30 for this parallel run (total 30)...
# Building estimator 26 of 30 for this parallel run (total 30)...
# Building estimator 27 of 30 for this parallel run (total 30)...
# Building estimator 28 of 30 for this parallel run (total 30)...
# Building estimator 29 of 30 for this parallel run (total 30)...
# Building estimator 30 of 30 for this parallel run (total 30)...
# Building estimator 1 of 30 for this parallel run (total 30)...
# Building estimator 2 of 30 for this parallel run (total 30)...
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.8s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.8s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Building estimator 3 of 30 for this parallel run (total 30)...
# Building estimator 4 of 30 for this parallel run (total 30)...
# Building estimator 5 of 30 for this parallel run (total 30)...
# Building estimator 6 of 30 for this parallel run (total 30)...
# Building estimator 7 of 30 for this parallel run (total 30)...
# Building estimator 8 of 30 for this parallel run (total 30)...
# Building estimator 9 of 30 for this parallel run (total 30)...
# Building estimator 10 of 30 for this parallel run (total 30)...
# Building estimator 11 of 30 for this parallel run (total 30)...
# Building estimator 12 of 30 for this parallel run (total 30)...
# Building estimator 13 of 30 for this parallel run (total 30)...
# Building estimator 14 of 30 for this parallel run (total 30)...
# Building estimator 15 of 30 for this parallel run (total 30)...
# Building estimator 16 of 30 for this parallel run (total 30)...
# Building estimator 17 of 30 for this parallel run (total 30)...
# Building estimator 18 of 30 for this parallel run (total 30)...
# Building estimator 19 of 30 for this parallel run (total 30)...
# Building estimator 20 of 30 for this parallel run (total 30)...
# Building estimator 21 of 30 for this parallel run (total 30)...
# Building estimator 22 of 30 for this parallel run (total 30)...
# Building estimator 23 of 30 for this parallel run (total 30)...
# Building estimator 24 of 30 for this parallel run (total 30)...
# Building estimator 25 of 30 for this parallel run (total 30)...
# Building estimator 26 of 30 for this parallel run (total 30)...
# Building estimator 27 of 30 for this parallel run (total 30)...
# Building estimator 28 of 30 for this parallel run (total 30)...
# Building estimator 29 of 30 for this parallel run (total 30)...
# Building estimator 30 of 30 for this parallel run (total 30)...
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.6s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.6s finished
# SkopeRules(feature_names=array(['Gamma_AATA', 'Gamma_IPPS', 'Gamma_IPPSm', ...,
#        'sigma_km_product1_r_4235', 'sigma_km_substrate2_r_4235',
#        'sigma_km_product2_r_4235'], dtype=object),
#            max_depth=5, max_depth_duplication=4, max_samples=0.7,
#            n_estimators=30, precision_min=0.9, random_state=42, recall_min=0.05,
#            verbose=2)

# %%
print(str(len(skope_rules_clf.rules_)) + ' rules have been built with ' +
      'SkopeRules.\n')

for i_rule, rule in enumerate(skope_rules_clf.rules_[:4]):
    print(rule[0])
# Out:
# 29 rules have been built with SkopeRules.
#
# Gamma_FBA <= -0.9118080735206604 and sigma_km_product1_ALCD26xi > -0.26216644048690796 and sigma_km_substrate1_ASPTA <= 1.1930022835731506
# sigma_km_substrate2_VALTAim <= 1.3757104873657227 and Gamma_2PHETOHtm <= -1.313053548336029 and sigma_km_substrate1_ADK1 <= 1.5514056086540222 and sigma_km_product1_ICDHxm > -0.03848084434866905 and sigma_km_substrate2_ILETAm <= 1.3645450472831726
# sigma_km_substrate1_ADK1 <= 1.5514056086540222 and Gamma_ORNTA <= -1.0557992458343506 and sigma_km_product1_ICDHxm > 0.05641191266477108 and sigma_km_substrate26_LMPD_s_0450_c_1_256 <= 0.3245595768094063
# sigma_km_substrate1_ADK1 <= 1.5514056086540222 and Gamma_GLUDC <= -1.3166851997375488 and sigma_km_product_HCO3E > -1.57037752866745 and sigma_km_product1_ICDHxm > 0.33645980060100555

# %% [markdown]
# # Validation set
#
# ## Rule 1:
#
# -  iGamma_FBA <= -0.9118080735206604 and sigma_km_product1_ALCD26xi > -0.26216644048690796 and sigma_km_substrate1_ASPTA <= 1.1930022835731506
#
#
#
# Sample from test set rows based on __Rule 1__ (_Validation set_)

# %%
index_GP = X_test[(X_test['Gamma_FBA'] <= -0.9118080735206604) 
                & (X_test['sigma_km_product1_ALCD26xi'] > -0.26216644048690796)
                & (X_test['sigma_km_substrate1_ASPTA'] <= 1.1930022835731506)].index

len(index_GP)
# Out:
# 11

# %%
y_val = y_test.loc[index_GP]
SI_val = y_val['Stability'].value_counts()[1] / len(y_val)
print("The Stability Index on VALIDATION SET (sampled from TEST SET) is: SI =",round(SI_val, 4), "%")

print("The Stability Index on TEST SET is: SI =",round(SI_test, 4), "%")
# Out:
# The Stability Index on VALIDATION SET (sampled from TEST SET) is: SI = 0.9091 %
# The Stability Index on TEST SET is: SI = 19.8473 %
